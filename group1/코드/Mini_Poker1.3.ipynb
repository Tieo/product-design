# %%
# -*- conding: utf-8 -*-
#import numpy   as np
import random
import copy
import time

# %%
class Environment:
    #게임판 구성, 안되는 상태, 완료된 상태, 보상 정의
    #게임판 핸드만 두장 줌, 베팅 한 번씩 물어봄. 리레이즈 1회만 가능

    # 덱을 만듬. 턴, 판돈, 플레이어가 베팅한 횟수 설정

    def __init__(self):
        self.done = False #True면 게임 종료
        #self.winner = 0
        self.reward = 0
        self.turn = 0
        self.table = 0
        self.player_calls =0
        self.lowlimit = 200
        self.maxlimit = 2000
        self.bet1 = -2
        self.bet2 = -2

        deck = [(suit, i) for suit in ["s", "h", "d", "c"] for i in range(2, 15)]  ##카드 덱 만들기, 튜플로 구성된 리스트
        random.shuffle(deck)
        self.deck = deck

    # 보상을 정의  handcheck, ai_action은 agent가 준다.
    def pf_reward(self, handcheck, ai_action):
        #print('hc, a', handcheck, ai_action)
        if (handcheck == 1) and (ai_action > 0):
            # if ai_action >= 0:  # 콜, 레이즈, 체크
            rwd = -1
        elif (handcheck == 1) and (ai_action < 0):  # 폴드한 경우
            rwd = +1

        elif (handcheck != 1) and (ai_action > 0):
            # if ai_action >= 0:  # 콜, 레이즈, 체크
            rwd = +1
        else:  # 폴드한 경우
            rwd = -1

        return rwd

    def move(self, p1,p2):
        #각플레이어가 선택한 행동 table에 반영하고 게임 상태 판단
        #p1 = 1, p2 = -1
        #각 플레이어는 행동을 선택하는 메서드를 가짐 selct_action
        
        self.table += 400 # Blind 
        p1.bal -= 200
        p2.bal -= 200

        self.bet1 = p1.select_action(env)
        if self.bet1 == -1: #폴드한 경우
          pass
        else:
          self.table += self.bet1
        self.player_calls += 1
        #else:
        self.bet2 = p2.select_action(env)#, player)
        if self.bet2 > self.lowlimit: #리레이즈시
          self.table += self.bet2
          self.bet1 = p1.select_action(env) # 한번 더 행동을 받음
          if self.bet1 == -1:
            pass
          else:
            self.table += self.bet1
          self.player_calls += 1
        else:
          if self.bet2 == -1:
            pass
          else:
            self.table += self.bet2
          self.player_calls += 1

        #게임 상태가 종료인지 판단, 누가 이겼는지 체크
        self.end_check(p1,p2)
        self.player_calls =0
        return self.reward, self.done

    #현재 베팅 가능한 상태 수집.
    def get_action(self):
        observation = [-1,0]
        #table이 0이 아니다. -> 누군가 베팅을 했다면 lowlimit 이 그 두배로 바뀜

        if self.table > 400:
          if self.table*2 > 2000:
            self.lowlimit = 2000
          else:
            self.lowlimit =  self.table*2
        
        for i in range(self.lowlimit, self.maxlimit+1,10): #이 부분 변경하면 경우의 수를 줄일 수 있음.
            observation.append(i)
        return observation

    #게임 종료 판단
    def end_check(self, p1,p2):
        if self.player_calls == 2:

            #판돈에 플레이어의 베팅을 반영 및 표시
            if (self.bet1 == -1): #P1 폴드 
              p2.bal += self.table
              self.table = 0
              self.reward = -1 # 승자는 p2
              self.done = True
              
            elif (self.bet2 == -1): # P2 폴드
              p1.bal += self.table
              self.table = 0
              self.reward = 1 #승자는 p1
              self.done = True
              
            else: # 카드 점수 계산 
              # 1. p1 승리
              if self.hand_check(p1.hand1, p1.hand2) > self.hand_check(p2.hand1, p2.hand2):
                  self.reward = 1
                  p1.bal += self.table  # 테이블의 돈을 가져감
                  self.table = 0
                  self.done = True
              # 2. p2 승리
              elif self.hand_check(p1.hand1, p1.hand2) < self.hand_check(p2.hand1, p2.hand2):
                  self.reward = -1
                  p2.bal += self.table  # 테이블의 돈을 가져감
                  self.table = 0
                  self.done = True
              # 3. p1 p2카드가 같다. -> 무승부 판돈 분할
              else:
                  self.reward = 0
                  p1.bal += self.table/2
                  p2.bal += self.table/2
                  self.table = 0
                  self.done = True # 돈은 그대로 남아있음.
        else:
            pass
        return

    def print_poker(self, player):
        print('\n------------------Turn : %d-------------------\n'%self.turn)
        print('Table Money: %d'%self.table)
        print('Now Bet: %s'%player.name)

    # 핸드 순위 확인
    def hand_check(self, hand1, hand2):  # 핸드체크, 프레플랍 단계 먼저 자신에게 주어진 카드 정보를 분석한다.
        premium = [('p', 14, 14), ('p', 13, 13), ('p', 12, 12), ('s', 14, 13), ('p', 11, 11), ('s', 14, 12),
                   ('s', 13, 12), ('s', 14, 11), ('s', 13, 11), ('p', 10, 10), ('o', 14, 13), ('s', 14, 10),
                   ('s', 12, 11), ('s', 13, 10), ('s', 12, 10), ('s', 11, 10), ('p', 9, 9)]
        special = [('o', 14, 12), ('s', 14, 9), ('o', 13, 12), ('p', 8, 8), ('s', 13, 9), ('s', 10, 9),
                   ('s', 14, 8),
                   ('s', 12, 9), ('s', 11, 9), ('o', 14, 11), ('s', 14, 5), ('p', 7, 7), ('s', 14, 7),
                   ('o', 13, 11),
                   ('s', 14, 4), ('s', 14, 3), ('s', 14, 6)]
        good = [('o', 12, 11), ('p', 6, 6), ('s', 13, 8), ('s', 10, 8), ('s', 14, 2), ('s', 9, 8), ('s', 11, 8),
                ('o', 14, 10), ('s', 12, 8), ('s', 13, 7), ('o', 13, 10), ('p', 5, 5), ('o', 11, 10), ('s', 8, 7),
                ('o', 12, 10), ('p', 4, 4), ('p', 3, 3), ('p', 2, 2)]
        # 숫자 비교 후 pair인지 확인(pair이면 p, 아니면 문자 확인으로 넘어감), 문자 확인해서 일치하는지 확인(불일치 하면 o, 일치하면 s ),  숫자 조합해서 하나의 튜플로 제작
        if hand1[1] == hand2[1]:
            tup1 = 'p'
        else:
            if hand1[0] == hand2[0]:
                tup1 = 's'
            else:
                tup1 = 'o'

        if hand1[1] > hand2[1]:  # 숫자 큰 게 앞으로 오게 함
            tup2, tup3 = hand1[1], hand2[1]
        else:
            tup2, tup3 = hand2[1], hand1[1]

        tup = (tup1, tup2, tup3)  # 튜플 생성
        #print('tup', tup)
        if premium.count(tup) == 1:
            return 4  # ('premium')
        elif special.count(tup) == 1:
            return 3  # ('special')
        elif good.count(tup) == 1:  # 판단
            return 2  # ('good')
        else:
            return 1  # ('fold')

# %%
class Human_player:
    
    
    def __init__(self):
        self.name = 'Human Player'
        self.bal = 50000
        self.hand1 = 0
        self.hand2 = 0
    
    
    def select_action(self, env):#,player):
        while True:
            available_action = env.get_action()
            if (env.bet1 > 0) and (env.bet2> 2*env.bet1): #리레이즈의 상황이라면 
              available_action = [-1, env.bet2-env.bet1] #폴드하거나 콜만 함
            
            
            
            if action in available_action:
              if action == 0: # 콜/체크라면 상대가 제시한 만큼 내게 됨. 추후 라운드 추가시 변경
                self.bal -= env.table
                env.table += env.table 
              self.bal -= action
              return action
            else:
                print("Wrong Action. Try Again")
        return

# %%
class Random_player:
    
    def __init__(self):
        self.name = 'Random Player'
        self.bal = 50000
        self.hand1 = 0
        self.hand2 = 0

    def select_action(self, env):
        
        available_action = env.get_action()
        #print(env.bet1)
        if (env.bet1 > 0) and (env.bet2> 2*env.bet1): #리레이즈의 상황이라면 
          available_action = [-1, env.bet2-env.bet1] #폴드, 콜만 함

        action = random.choice(available_action) # 임의로 행동 선택
       
        if action == 0: # 콜/체크라면 상대가 제시한 만큼 내게 됨. 추후 라운드 추가시 변경
          self.bal -= env.table
          env.table += env.table
        if action == -1:
          pass
        else:
          self.bal -= action
        return action

# %%
class Monte_Carlo_player:
  def __init__(self):
    self.name = "MC player"
    self.num_playout = 10 # 최대 약 1800 
    self.bal = 50000
    self.hand1 = 0
    self.hand2 = 0
    

  def select_action(self, env):
    #가능한 행동 조사
    available_action = env.get_action()
    if (env.bet1 > 0) and (env.bet2> 2*env.bet1): #리레이즈의 상황이라면 
      available_action = [-1, env.bet2-env.bet1] #폴드하거나 콜만 함
    
    Q_val_dict = {} # 모든 카드의 경우의 수와 점수 쌍을 모을 딕셔너리 {'카드1,카드2,' : [0, 0, ... ,0]} 의 형태 

    total_action = [-1, 0] # 게임에서 가능한 모든 행동 
    for i in range(200,2001):
      total_action.append(i)
    
    T = [] # 게임상 가능한 행동 개수만큼 0으로 채운 점수판 생성
    for i in range(1803):
      T.append(0)

    temp_p1 = Random_player
    temp_p1.name = p1.name
    temp_p1.bal = p1.bal

    temp_p2 = Random_player()
    temp_p2.name = p2.name
    temp_p2.bal = p2.bal

    if temp_p1.name == 'MC player':
      temp_p1.hand1 = p1.hand1
      temp_p1.hand2 = p1.hand2
      
      temp_p1_deck = (temp_p1.hand1, temp_p1.hand2)
    
    if temp_p2.name == 'MC player':
      temp_p2.hand1 = p2.hand1
      temp_p2.hand2 = p2.hand2
      
      temp_p2_deck = (temp_p2.hand1, temp_p2.hand2)
    
    for i in range(len(available_action)):

      #플레이아웃을 1000번 반복
      for j in range(self.num_playout):

        #지금 상태를 복사해서 블레이 아웃에 사용
        temp_env = copy.deepcopy(env)
        
        deck = [(suit, i) for suit in ["s", "h", "d", "c"] for i in range(2, 15)]  ##카드 덱 만들기, 튜플로 구성된 리스트
        random.shuffle(deck) # 플레이아웃용 deck 만들기 
        
        if temp_p1.name == 'MC player':
          deck.remove(temp_p1.hand1)
          deck.remove(temp_p1.hand2)
          
          temp_env.deck = deck
          temp_p2.hand1, temp_p2.hand2 = deck.pop(), deck.pop()

        if temp_p2.name == 'MC player':
          deck.remove(temp_p2.hand1)
          deck.remove(temp_p2.hand2)
          
          temp_env.deck = deck
          temp_p1.hand1, temp_p1.hand2 = deck.pop(), deck.pop()


        if temp_p1.name == 'MC player':
          if temp_p1_deck not in Q_val_dict.keys():
            Q_val_dict[temp_p1_deck] = T #이전에 존재하지 않은 p1의 덱이라면 모든 행동 길이만큼의 점수판 리스트를 val 값으로 가짐
        if temp_p2.name == 'MC player':
          if temp_p2_deck not in Q_val_dict.keys():
            Q_val_dict[temp_p2_deck] = T
          

        self.playout(temp_env, available_action[i], temp_p1, temp_p2) # 가상 게임 실행, 현재 가능한 행동 안에서 루프를 수행함. 
        #플레이 아웃의 결과는 승리 플레이어의 값으로 반환
        #p1이 이기면 reward = 1, p2가 이기면 reward = -1

        if temp_p1.name == 'MC player':
          result_point = Q_val_dict[temp_p1_deck]
        if temp_p2.name == 'MC player':
          result_point = Q_val_dict[temp_p2_deck]

        if temp_p1.name == 'MC player': #p1이 MC일 때 
          if temp_env.reward == 1: #p1이 승리한 경우
            result_point[total_action.index(temp_env.bet1)] += 1 # p1이 베팅한 금액이 게임상 가능한 액션 중에 몇 번째인지 점수판으로 가져와서 해당 인덱스에 +1
        if temp_p2.name == 'MC player':
          if temp_env.reward == -1:
            result_point[total_action.index(temp_env.bet2)] += 1 # p1이 베팅한 금액이 게임상 가능한 액션 중에 몇 번째인지 점수판으로 가져와서 해당 인덱스에 +1
           
    action_index = result_point.index(max(result_point)) # 점수판에서 최대인 지점의 인덱스를 가져옴
    action = total_action[action_index] # 게임상 가능한 모든 행동 중에서 가져온 인덱스에 있는 베팅값 제시 
    
    if action == 0: # 콜/체크라면 상대가 제시한 만큼 내게 됨. 추후 라운드 추가시 변경
          self.bal -= env.table
          env.table += env.table
    if action == -1:
      pass
    else:
      self.bal -= action
    return action

  #플레이아웃 재귀 함수
  # 게임이 종료 상태(승/패/비김)가 될 때까지 행동을 임의로 선택하는 것을 반복
  def playout(self, temp_env, action,temp_p1, temp_p2):#, player):
    #판돈에 플레이어의 베팅을 반영 및 표시
  
    if temp_p1.name == 'MC player':
      temp_env.bet1 = action
      temp_env.table += temp_env.bet1
    if temp_p2.name == 'MC player':
      temp_env.bet2 = action
      temp_env.table += temp_env.bet2
    temp_env.player_calls += 1
    
 
     #게임 종료 체크 
    if temp_env.player_calls == 2:
      temp_env.end_check(temp_p1, temp_p2)
      temp_env.player_calls =0

      return 

    else:
      #가능한 행동 조사 
      #a무작위로 행동을 선택
      if temp_p1.name == 'MC player':
        temp_env.bet2 = temp_p2.select_action(temp_env)
        temp_env.table += temp_env.bet2
      if temp_p2.name == 'MC player':
        temp_env.bet1 = temp_p1.select_action(temp_env)
        temp_env.table += temp_env.bet2
      temp_env.player_calls += 1

# %%
#p1 = Monte_Carlo_player()
p1 = Random_player()
#p1 = Human_player()
#p2 = Random_player()
p2 = Monte_Carlo_player()
#p2 = Human_player()

# 지정된 게임 수를 자동으로 두게 할 것인지 한 게임씩 두게 할 것인지 결정
# auto = True : 지정된 판 수 (games)를 자동으로 진행
# auto = Flase: 한 게임씩 진행
auto = True

#auto 모드의 게임 수
games = 1000

#각 플레이어의 승리 횟수를 저장
p1_score = 0
p2_score = 0
draw_score = 0

# %%
start = time.time()
if auto:

    #자동모드 실행
    for j in range(games):
        np.random.seed(j)
        env = Environment()
        p1.hand1, p1.hand2 = env.deck.pop(), env.deck.pop()
        p2.hand1, p2.hand2 = env.deck.pop(), env.deck.pop()
        print('\n------------------------------------------------------------------------------------------------------------------')
        print("p1 player, money, hand : {} {} {}{}".format(p1.name, p1.bal, p1.hand1, p1.hand2))
        print("p2 player, money hand: {} {} {}{}".format(p2.name, p2.bal, p2.hand1, p2.hand2))
        
        if (p1.bal < 0) or (p2.bal <0):
          print('Player Balance Under 0, End this Game.\n')
          break
        for i in range(10000):
            # p1, p2 번갈아가면서 게임을 진행
            # p1(1) -> p2(-1)
            sum = p1.bal+p2.bal
           
            reward, done = env.move(p1,p2) #,(-1)**i)
            print('after move',sum, env.bet1, env.bet2)
            if sum != 100000:
              print('after move',sum, env.bet1, env.bet2)
              input()
            print('reward', reward)
            # 게임 종료 체크
            if done == True:
                if reward == 1:
                    print("j = {} winner is p1({})".format(j, p1.name))
                    p1_score += 1
                elif reward == -1:
                    print("j = {} winner is p2({})".format(j, p2.name))
                    p2_score += 1
                else:
                    print("j = {} winner is draw".format(j))
                    draw_score += 1
                break
    print("Good Game!")
    print("\n현재 라운드: {}\n{} 승리 횟수: {} {} 승리 횟수: {} 비긴 횟수: {}".format(j, p1.name, p1_score, p2.name, p2_score, draw_score))
    print("{} 잔고: {}, {} 잔고: {} 잔고합계 {}".format(p1.name, p1.bal, p2.name, p2.bal, p1.bal+p2.bal))
    print("수행 시간: {}".format(time.time() - start))
    
else:
    #한 게임씩 진행하는 수동 모드
    while True:
        #env = Environment()
        env = Environment()
        p1.hand1, p1.hand2 = env.deck.pop(), env.deck.pop()
        p2.hand1, p2.hand2 = env.deck.pop(), env.deck.pop()
        print('------------------------------------------------------------------------------------------------------------------')
        print("p1 player, money, hand : {} {} {}{}".format(p1.name, p1.bal, p1.hand1, p1.hand2))
        print("p2 player, money hand: {} {} {}{}".format(p1.name, p2.bal, p2.hand1, p2.hand2))
        #print('------------------------------------------------------------------------------------------------------------------')
        #env.print = True

        for i in range(10000):
            # p1, p2 번갈아가면서 게임을 진행
            # p1(1) -> p2(-1)
            reward, done = env.move(p1, p2, (-1)**i)
            print('reward', reward)
            # 게임 종료 체크
            if done == True:
                if reward == 1:
                    print("Winner is p1({})".format(p1.name))
                    p1_score += 1
                elif reward == -1:
                    print("Winner is p2({})".format(p2.name))
                    p2_score += 1
                else:
                    print("No Winner")
                    draw_score += 1
                break

        print("final result")
        env.print_poker(p1)

        print("final result")
        env.print_poker(p2)

        # one more?
        answer = input("more Game? (y/n)")
        print("table= {} p1({}) = {} p2({}) = {} draw = {}".format(env.table, p1.name, p1_score, p2.name, p2_score, draw_score))
        if answer == 'y':
            pass
        else:
            print("Good Game!")
            print("\n현재 라운드: {}\n{} 승리 횟수: {} {} 승리 횟수: {} 비긴 횟수: {}".format(j, p1.name, p1_score, p2.name, p2_score, draw_score))
            print("{} 잔고: {}, {} 잔고: {} 잔고합계 {}".format(p1.name, p1.bal, p2.name, p2.bal, p1.bal+p2.bal))
            print("수행 시간: {}".format(time.time() - start))
# Out:
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 50000 ('h', 6)('h', 2)
# p2 player, money hand: MC player 50000 ('s', 7)('c', 13)
# after move 100000 1550 -1
# reward 1
# j = 0 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 50200 ('h', 5)('s', 2)
# p2 player, money hand: MC player 49800 ('s', 11)('s', 10)
# after move 100000 610 2000
# reward -1
# j = 1 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 49390 ('s', 7)('d', 8)
# p2 player, money hand: MC player 50610 ('c', 5)('h', 14)
# after move 100000 1590 -1
# reward 1
# j = 2 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 49590 ('h', 10)('h', 2)
# p2 player, money hand: MC player 50410 ('s', 6)('c', 13)
# after move 100000 420 -1
# reward 1
# j = 3 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 49790 ('s', 14)('h', 14)
# p2 player, money hand: MC player 50210 ('c', 5)('d', 6)
# after move 100000 1770 -1
# reward 1
# j = 4 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 49990 ('d', 7)('c', 14)
# p2 player, money hand: MC player 50010 ('c', 2)('h', 13)
# after move 100000 1500 -1
# reward 1
# j = 5 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 50190 ('s', 10)('d', 7)
# p2 player, money hand: MC player 49810 ('d', 13)('d', 8)
# after move 100000 1230 0
# reward -1
# j = 6 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 48760 ('d', 3)('h', 12)
# p2 player, money hand: MC player 51240 ('h', 13)('s', 8)
# after move 100000 1220 -1
# reward 1
# j = 7 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 48960 ('s', 8)('h', 14)
# p2 player, money hand: MC player 51040 ('h', 11)('d', 8)
# after move 100000 920 -1
# reward 1
# j = 8 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 49160 ('s', 10)('c', 5)
# p2 player, money hand: MC player 50840 ('h', 2)('d', 13)
# after move 100000 850 -1
# reward 1
# j = 9 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 49360 ('c', 10)('c', 3)
# p2 player, money hand: MC player 50640 ('s', 3)('h', 3)
# after move 100000 1430 0
# reward -1
# j = 10 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 47730 ('d', 9)('h', 8)
# p2 player, money hand: MC player 52270 ('s', 12)('c', 9)
# after move 100000 1330 -1
# reward 1
# j = 11 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 47930 ('h', 2)('d', 11)
# p2 player, money hand: MC player 52070 ('h', 12)('c', 7)
# after move 100000 1010 -1
# reward 1
# j = 12 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 48130 ('c', 3)('h', 9)
# p2 player, money hand: MC player 51870 ('c', 4)('c', 2)
# after move 100000 1700 -1
# reward 1
# j = 13 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 48330 ('d', 3)('d', 6)
# p2 player, money hand: MC player 51670 ('h', 8)('c', 10)
# after move 100000 1120 -1
# reward 1
# j = 14 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 48530 ('s', 12)('d', 9)
# p2 player, money hand: MC player 51470 ('h', 6)('d', 6)
# after move 100000 1380 1930
# reward -1
# j = 15 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 46400 ('c', 2)('s', 4)
# p2 player, money hand: MC player 53600 ('d', 14)('c', 4)
# after move 100000 1490 -1
# reward 1
# j = 16 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 46600 ('c', 6)('d', 14)
# p2 player, money hand: MC player 53400 ('d', 2)('c', 5)
# after move 100000 850 -1
# reward 1
# j = 17 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 46800 ('s', 2)('c', 13)
# p2 player, money hand: MC player 53200 ('s', 14)('c', 12)
# after move 100000 450 0
# reward -1
# j = 18 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 46150 ('c', 7)('c', 6)
# p2 player, money hand: MC player 53850 ('h', 8)('s', 4)
# after move 100000 670 -1
# reward 1
# j = 19 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 46350 ('c', 8)('s', 5)
# p2 player, money hand: MC player 53650 ('d', 5)('h', 6)
# after move 100000 0 -1
# reward 1
# j = 20 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 46550 ('s', 2)('h', 13)
# p2 player, money hand: MC player 53450 ('c', 5)('c', 6)
# after move 100000 680 -1
# reward 1
# j = 21 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 46750 ('c', 12)('h', 6)
# p2 player, money hand: MC player 53250 ('s', 14)('c', 10)
# after move 100000 1300 2000
# reward -1
# j = 22 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 45250 ('d', 6)('s', 5)
# p2 player, money hand: MC player 54750 ('d', 7)('d', 8)
# after move 100000 1980 0
# reward -1
# j = 23 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 43070 ('d', 13)('s', 5)
# p2 player, money hand: MC player 56930 ('h', 5)('c', 5)
# after move 100000 1610 2000
# reward -1
# j = 24 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 41260 ('s', 5)('s', 13)
# p2 player, money hand: MC player 58740 ('s', 14)('s', 7)
# after move 100000 860 0
# reward -1
# j = 25 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 40200 ('d', 2)('h', 7)
# p2 player, money hand: MC player 59800 ('h', 6)('d', 4)
# after move 100000 1730 -1
# reward 1
# j = 26 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 40400 ('d', 12)('s', 2)
# p2 player, money hand: MC player 59600 ('s', 4)('h', 7)
# after move 100000 1600 -1
# reward 1
# j = 27 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 40600 ('d', 10)('h', 6)
# p2 player, money hand: MC player 59400 ('h', 9)('c', 5)
# after move 100000 1090 -1
# reward 1
# j = 28 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 40800 ('d', 3)('s', 5)
# p2 player, money hand: MC player 59200 ('s', 7)('d', 9)
# after move 100000 1320 -1
# reward 1
# j = 29 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 41000 ('s', 14)('s', 7)
# p2 player, money hand: MC player 59000 ('c', 11)('c', 14)
# after move 100000 380 1560
# reward -1
# j = 30 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 40420 ('d', 9)('c', 10)
# p2 player, money hand: MC player 59580 ('d', 11)('h', 4)
# after move 100000 920 -1
# reward 1
# j = 31 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 40620 ('s', 11)('d', 9)
# p2 player, money hand: MC player 59380 ('d', 6)('h', 5)
# after move 100000 810 -1
# reward 1
# j = 32 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 40820 ('d', 7)('c', 5)
# p2 player, money hand: MC player 59180 ('h', 13)('h', 11)
# after move 100000 210 1220
# reward -1
# j = 33 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 40410 ('s', 12)('c', 8)
# p2 player, money hand: MC player 59590 ('c', 10)('c', 6)
# after move 100000 1130 -1
# reward 1
# j = 34 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 40610 ('h', 11)('d', 7)
# p2 player, money hand: MC player 59390 ('s', 9)('d', 3)
# after move 100000 1230 -1
# reward 1
# j = 35 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 40810 ('d', 8)('h', 7)
# p2 player, money hand: MC player 59190 ('c', 4)('d', 7)
# after move 100000 600 -1
# reward 1
# j = 36 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 41010 ('h', 10)('c', 8)
# p2 player, money hand: MC player 58990 ('c', 6)('d', 6)
# after move 100000 1870 2000
# reward -1
# j = 37 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 38940 ('s', 13)('d', 6)
# p2 player, money hand: MC player 61060 ('c', 4)('c', 7)
# after move 100000 260 -1
# reward 1
# j = 38 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 39140 ('s', 7)('s', 10)
# p2 player, money hand: MC player 60860 ('h', 2)('d', 6)
# after move 100000 1390 -1
# reward 1
# j = 39 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 39340 ('d', 14)('s', 9)
# p2 player, money hand: MC player 60660 ('h', 3)('c', 6)
# after move 100000 490 -1
# reward 1
# j = 40 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 39540 ('s', 2)('c', 10)
# p2 player, money hand: MC player 60460 ('s', 14)('s', 7)
# after move 100000 1700 0
# reward -1
# j = 41 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 37640 ('d', 14)('d', 7)
# p2 player, money hand: MC player 62360 ('d', 11)('c', 6)
# after move 100000 620 -1
# reward 1
# j = 42 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 37840 ('s', 10)('h', 3)
# p2 player, money hand: MC player 62160 ('c', 5)('d', 4)
# after move 100000 1290 -1
# reward 1
# j = 43 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 38040 ('d', 3)('s', 9)
# p2 player, money hand: MC player 61960 ('d', 2)('s', 12)
# after move 100000 1710 -1
# reward 1
# j = 44 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 38240 ('h', 2)('s', 14)
# p2 player, money hand: MC player 61760 ('d', 13)('c', 11)
# after move 100000 -1 1930
# reward -1
# j = 45 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 37500 ('d', 13)('d', 5)
# p2 player, money hand: MC player 62500 ('s', 14)('s', 11)
# after move 100000 1860 2000
# reward -1
# j = 46 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 35440 ('s', 2)('s', 3)
# p2 player, money hand: MC player 64560 ('c', 8)('h', 9)
# after move 100000 1730 -1
# reward 1
# j = 47 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 35640 ('d', 6)('s', 14)
# p2 player, money hand: MC player 64360 ('c', 13)('d', 3)
# after move 100000 1550 -1
# reward 1
# j = 48 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 35840 ('c', 4)('h', 12)
# p2 player, money hand: MC player 64160 ('c', 7)('h', 6)
# after move 100000 1590 -1
# reward 1
# j = 49 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 36040 ('c', 2)('h', 2)
# p2 player, money hand: MC player 63960 ('s', 7)('d', 10)
# after move 100000 800 -1
# reward 1
# j = 50 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 36240 ('d', 4)('h', 5)
# p2 player, money hand: MC player 63760 ('d', 8)('d', 6)
# after move 100000 1390 -1
# reward 1
# j = 51 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 36440 ('h', 8)('h', 6)
# p2 player, money hand: MC player 63560 ('h', 5)('d', 4)
# after move 100000 470 -1
# reward 1
# j = 52 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 36640 ('h', 7)('c', 5)
# p2 player, money hand: MC player 63360 ('c', 11)('c', 6)
# after move 100000 910 -1
# reward 1
# j = 53 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 36840 ('d', 6)('h', 11)
# p2 player, money hand: MC player 63160 ('d', 2)('s', 9)
# after move 100000 1110 -1
# reward 1
# j = 54 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 37040 ('s', 7)('s', 3)
# p2 player, money hand: MC player 62960 ('h', 12)('s', 14)
# after move 100000 1040 0
# reward -1
# j = 55 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 35800 ('c', 11)('d', 14)
# p2 player, money hand: MC player 64200 ('s', 14)('d', 4)
# after move 100000 1270 -1
# reward 1
# j = 56 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 36000 ('d', 8)('h', 14)
# p2 player, money hand: MC player 64000 ('h', 2)('c', 5)
# after move 100000 1840 -1
# reward 1
# j = 57 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 36200 ('c', 2)('c', 6)
# p2 player, money hand: MC player 63800 ('c', 4)('s', 7)
# after move 100000 1070 -1
# reward 1
# j = 58 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 36400 ('c', 2)('h', 14)
# p2 player, money hand: MC player 63600 ('c', 9)('h', 7)
# after move 100000 500 -1
# reward 1
# j = 59 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 36600 ('d', 13)('s', 8)
# p2 player, money hand: MC player 63400 ('c', 6)('d', 2)
# after move 100000 1930 -1
# reward 1
# j = 60 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 36800 ('c', 5)('h', 13)
# p2 player, money hand: MC player 63200 ('c', 3)('c', 8)
# after move 100000 1460 -1
# reward 1
# j = 61 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 37000 ('d', 11)('s', 12)
# p2 player, money hand: MC player 63000 ('h', 9)('c', 3)
# after move 100000 1480 -1
# reward 1
# j = 62 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 37200 ('h', 2)('s', 3)
# p2 player, money hand: MC player 62800 ('d', 8)('h', 9)
# after move 100000 1790 -1
# reward 1
# j = 63 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 37400 ('c', 3)('s', 6)
# p2 player, money hand: MC player 62600 ('h', 14)('h', 5)
# after move 100000 640 0
# reward -1
# j = 64 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 36560 ('c', 3)('c', 6)
# p2 player, money hand: MC player 63440 ('d', 9)('c', 14)
# after move 100000 260 -1
# reward 1
# j = 65 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 36760 ('s', 2)('c', 11)
# p2 player, money hand: MC player 63240 ('c', 14)('h', 8)
# after move 100000 220 -1
# reward 1
# j = 66 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 36960 ('d', 14)('s', 13)
# p2 player, money hand: MC player 63040 ('d', 8)('c', 4)
# after move 100000 300 -1
# reward 1
# j = 67 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 37160 ('c', 10)('c', 6)
# p2 player, money hand: MC player 62840 ('s', 7)('c', 13)
# after move 100000 320 -1
# reward 1
# j = 68 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 37360 ('d', 6)('d', 2)
# p2 player, money hand: MC player 62640 ('c', 13)('d', 7)
# after move 100000 1720 -1
# reward 1
# j = 69 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 37560 ('c', 2)('h', 4)
# p2 player, money hand: MC player 62440 ('s', 4)('h', 8)
# after move 100000 1830 -1
# reward 1
# j = 70 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 37760 ('c', 11)('h', 8)
# p2 player, money hand: MC player 62240 ('h', 14)('h', 10)
# after move 100000 1440 0
# reward -1
# j = 71 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 36120 ('d', 4)('s', 2)
# p2 player, money hand: MC player 63880 ('h', 10)('h', 13)
# after move 100000 1270 2000
# reward -1
# j = 72 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 34650 ('h', 4)('h', 7)
# p2 player, money hand: MC player 65350 ('c', 6)('h', 11)
# after move 100000 950 -1
# reward 1
# j = 73 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 34850 ('s', 6)('h', 3)
# p2 player, money hand: MC player 65150 ('d', 8)('c', 8)
# after move 100000 1990 0
# reward -1
# j = 74 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 32660 ('h', 5)('d', 12)
# p2 player, money hand: MC player 67340 ('c', 11)('h', 8)
# after move 100000 240 -1
# reward 1
# j = 75 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 32860 ('h', 14)('s', 2)
# p2 player, money hand: MC player 67140 ('h', 13)('c', 2)
# after move 100000 480 -1
# reward 1
# j = 76 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 33060 ('d', 14)('d', 9)
# p2 player, money hand: MC player 66940 ('d', 7)('s', 10)
# after move 100000 1550 -1
# reward 1
# j = 77 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 33260 ('c', 10)('h', 7)
# p2 player, money hand: MC player 66740 ('d', 4)('c', 7)
# after move 100000 710 -1
# reward 1
# j = 78 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 33460 ('h', 12)('d', 12)
# p2 player, money hand: MC player 66540 ('d', 14)('s', 7)
# after move 100000 1490 -1
# reward 1
# j = 79 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 33660 ('c', 8)('s', 6)
# p2 player, money hand: MC player 66340 ('c', 5)('s', 5)
# after move 100000 1940 2000
# reward -1
# j = 80 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 31520 ('d', 3)('c', 4)
# p2 player, money hand: MC player 68480 ('s', 6)('d', 2)
# after move 100000 550 -1
# reward 1
# j = 81 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 31720 ('c', 13)('h', 10)
# p2 player, money hand: MC player 68280 ('d', 7)('d', 8)
# after move 100000 460 0
# reward 0
# j = 82 winner is draw
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 31920.0 ('h', 8)('d', 6)
# p2 player, money hand: MC player 68080.0 ('d', 10)('h', 14)
# after move 100000.0 1550 0
# reward -1
# j = 83 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 30170.0 ('s', 14)('h', 3)
# p2 player, money hand: MC player 69830.0 ('c', 6)('h', 13)
# after move 100000.0 1370 -1
# reward 1
# j = 84 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 30370.0 ('s', 7)('s', 12)
# p2 player, money hand: MC player 69630.0 ('c', 5)('d', 13)
# after move 100000.0 940 -1
# reward 1
# j = 85 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 30570.0 ('h', 6)('c', 12)
# p2 player, money hand: MC player 69430.0 ('c', 3)('c', 13)
# after move 100000.0 1630 -1
# reward 1
# j = 86 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 30770.0 ('c', 14)('s', 12)
# p2 player, money hand: MC player 69230.0 ('c', 2)('s', 14)
# after move 100000.0 1670 -1
# reward 1
# j = 87 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 30970.0 ('d', 14)('s', 4)
# p2 player, money hand: MC player 69030.0 ('c', 8)('s', 3)
# after move 100000.0 1680 -1
# reward 1
# j = 88 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 31170.0 ('d', 3)('d', 6)
# p2 player, money hand: MC player 68830.0 ('c', 8)('s', 5)
# after move 100000.0 630 -1
# reward 1
# j = 89 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 31370.0 ('d', 7)('d', 13)
# p2 player, money hand: MC player 68630.0 ('d', 11)('s', 4)
# after move 100000.0 1190 -1
# reward 1
# j = 90 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 31570.0 ('c', 3)('d', 12)
# p2 player, money hand: MC player 68430.0 ('d', 7)('c', 14)
# after move 100000.0 1670 -1
# reward 1
# j = 91 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 31770.0 ('c', 7)('d', 10)
# p2 player, money hand: MC player 68230.0 ('s', 8)('h', 5)
# after move 100000.0 1800 -1
# reward 1
# j = 92 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 31970.0 ('s', 11)('c', 2)
# p2 player, money hand: MC player 68030.0 ('h', 8)('s', 7)
# after move 100000.0 1650 -1
# reward 1
# j = 93 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 32170.0 ('c', 12)('c', 8)
# p2 player, money hand: MC player 67830.0 ('c', 5)('d', 14)
# after move 100000.0 1480 -1
# reward 1
# j = 94 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 32370.0 ('h', 14)('h', 3)
# p2 player, money hand: MC player 67630.0 ('c', 5)('h', 2)
# after move 100000.0 1120 -1
# reward 1
# j = 95 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 32570.0 ('h', 9)('d', 12)
# p2 player, money hand: MC player 67430.0 ('d', 6)('s', 7)
# after move 100000.0 1750 -1
# reward 1
# j = 96 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 32770.0 ('d', 3)('h', 6)
# p2 player, money hand: MC player 67230.0 ('s', 7)('d', 6)
# after move 100000.0 0 -1
# reward 1
# j = 97 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 32970.0 ('c', 13)('c', 6)
# p2 player, money hand: MC player 67030.0 ('s', 8)('s', 2)
# after move 100000.0 1070 -1
# reward 1
# j = 98 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 33170.0 ('h', 3)('d', 7)
# p2 player, money hand: MC player 66830.0 ('s', 10)('c', 13)
# after move 100000.0 1890 2000
# reward -1
# j = 99 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 31080.0 ('s', 5)('h', 5)
# p2 player, money hand: MC player 68920.0 ('c', 4)('d', 7)
# after move 100000.0 1500 -1
# reward 1
# j = 100 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 31280.0 ('c', 3)('s', 10)
# p2 player, money hand: MC player 68720.0 ('s', 5)('s', 3)
# after move 100000.0 540 -1
# reward 1
# j = 101 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 31480.0 ('s', 10)('d', 14)
# p2 player, money hand: MC player 68520.0 ('s', 3)('s', 13)
# after move 100000.0 530 -1
# reward 1
# j = 102 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 31680.0 ('s', 12)('h', 3)
# p2 player, money hand: MC player 68320.0 ('h', 12)('d', 8)
# after move 100000.0 1180 -1
# reward 1
# j = 103 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 31880.0 ('s', 13)('c', 12)
# p2 player, money hand: MC player 68120.0 ('h', 13)('d', 2)
# after move 100000.0 550 -1
# reward 1
# j = 104 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 32080.0 ('h', 11)('d', 5)
# p2 player, money hand: MC player 67920.0 ('s', 13)('s', 12)
# after move 100000.0 1510 2000
# reward -1
# j = 105 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 30370.0 ('h', 12)('d', 13)
# p2 player, money hand: MC player 69630.0 ('c', 9)('h', 3)
# after move 100000.0 1640 -1
# reward 1
# j = 106 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 30570.0 ('c', 7)('s', 7)
# p2 player, money hand: MC player 69430.0 ('c', 14)('s', 3)
# after move 100000.0 1160 -1
# reward 1
# j = 107 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 30770.0 ('s', 8)('c', 7)
# p2 player, money hand: MC player 69230.0 ('h', 5)('d', 8)
# after move 100000.0 1360 -1
# reward 1
# j = 108 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 30970.0 ('s', 13)('c', 6)
# p2 player, money hand: MC player 69030.0 ('c', 4)('s', 2)
# after move 100000.0 300 -1
# reward 1
# j = 109 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 31170.0 ('d', 7)('h', 14)
# p2 player, money hand: MC player 68830.0 ('d', 14)('s', 5)
# after move 100000.0 1850 -1
# reward 1
# j = 110 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 31370.0 ('h', 13)('c', 2)
# p2 player, money hand: MC player 68630.0 ('s', 10)('h', 14)
# after move 100000.0 1450 0
# reward -1
# j = 111 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 29720.0 ('c', 2)('s', 3)
# p2 player, money hand: MC player 70280.0 ('d', 14)('c', 14)
# after move 100000.0 1840 0
# reward -1
# j = 112 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 27680.0 ('c', 8)('c', 13)
# p2 player, money hand: MC player 72320.0 ('c', 2)('s', 7)
# after move 100000.0 1620 -1
# reward 1
# j = 113 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 27880.0 ('h', 11)('d', 9)
# p2 player, money hand: MC player 72120.0 ('s', 12)('h', 12)
# after move 100000.0 980 0
# reward -1
# j = 114 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 26700.0 ('s', 6)('s', 4)
# p2 player, money hand: MC player 73300.0 ('s', 12)('c', 7)
# after move 100000.0 1400 -1
# reward 1
# j = 115 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 26900.0 ('s', 14)('c', 3)
# p2 player, money hand: MC player 73100.0 ('h', 5)('s', 2)
# after move 100000.0 590 -1
# reward 1
# j = 116 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 27100.0 ('c', 6)('c', 8)
# p2 player, money hand: MC player 72900.0 ('c', 14)('c', 4)
# after move 100000.0 1680 0
# reward -1
# j = 117 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 25220.0 ('c', 7)('d', 3)
# p2 player, money hand: MC player 74780.0 ('s', 5)('c', 4)
# after move 100000.0 1730 -1
# reward 1
# j = 118 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 25420.0 ('h', 8)('h', 4)
# p2 player, money hand: MC player 74580.0 ('h', 3)('s', 2)
# after move 100000.0 1970 -1
# reward 1
# j = 119 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 25620.0 ('d', 14)('h', 2)
# p2 player, money hand: MC player 74380.0 ('d', 4)('c', 12)
# after move 100000.0 340 -1
# reward 1
# j = 120 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 25820.0 ('h', 9)('c', 6)
# p2 player, money hand: MC player 74180.0 ('s', 6)('h', 14)
# after move 100000.0 1110 -1
# reward 1
# j = 121 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 26020.0 ('c', 7)('c', 12)
# p2 player, money hand: MC player 73980.0 ('c', 2)('d', 11)
# after move 100000.0 1500 -1
# reward 1
# j = 122 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 26220.0 ('c', 6)('d', 8)
# p2 player, money hand: MC player 73780.0 ('d', 6)('c', 13)
# after move 100000.0 1100 -1
# reward 1
# j = 123 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 26420.0 ('h', 12)('h', 13)
# p2 player, money hand: MC player 73580.0 ('s', 6)('c', 9)
# after move 100000.0 1750 -1
# reward 1
# j = 124 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 26620.0 ('c', 9)('c', 2)
# p2 player, money hand: MC player 73380.0 ('h', 10)('c', 7)
# after move 100000.0 540 -1
# reward 1
# j = 125 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 26820.0 ('d', 10)('c', 12)
# p2 player, money hand: MC player 73180.0 ('h', 4)('s', 11)
# after move 100000.0 1250 -1
# reward 1
# j = 126 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 27020.0 ('d', 13)('d', 14)
# p2 player, money hand: MC player 72980.0 ('c', 4)('c', 2)
# after move 100000.0 1870 -1
# reward 1
# j = 127 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 27220.0 ('s', 14)('h', 2)
# p2 player, money hand: MC player 72780.0 ('h', 3)('d', 9)
# after move 100000.0 -1 -1
# reward -1
# j = 128 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 27020.0 ('h', 2)('s', 3)
# p2 player, money hand: MC player 72980.0 ('s', 7)('c', 14)
# after move 100000.0 1480 -1
# reward 1
# j = 129 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 27220.0 ('d', 7)('h', 10)
# p2 player, money hand: MC player 72780.0 ('h', 6)('c', 6)
# after move 100000.0 700 0
# reward -1
# j = 130 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 26320.0 ('s', 5)('s', 10)
# p2 player, money hand: MC player 73680.0 ('s', 9)('h', 14)
# after move 100000.0 1710 -1
# reward 1
# j = 131 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 26520.0 ('c', 11)('c', 3)
# p2 player, money hand: MC player 73480.0 ('c', 10)('h', 8)
# after move 100000.0 1920 -1
# reward 1
# j = 132 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 26720.0 ('c', 8)('h', 9)
# p2 player, money hand: MC player 73280.0 ('s', 12)('c', 12)
# after move 100000.0 1090 0
# reward -1
# j = 133 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 25430.0 ('c', 3)('s', 6)
# p2 player, money hand: MC player 74570.0 ('h', 6)('s', 14)
# after move 100000.0 840 -1
# reward 1
# j = 134 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 25630.0 ('s', 7)('c', 6)
# p2 player, money hand: MC player 74370.0 ('c', 5)('s', 12)
# after move 100000.0 1860 -1
# reward 1
# j = 135 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 25830.0 ('h', 7)('c', 12)
# p2 player, money hand: MC player 74170.0 ('d', 3)('d', 14)
# after move 100000.0 1120 2000
# reward -1
# j = 136 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 24510.0 ('s', 8)('d', 9)
# p2 player, money hand: MC player 75490.0 ('h', 9)('s', 3)
# after move 100000.0 1900 -1
# reward 1
# j = 137 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 24710.0 ('h', 7)('c', 2)
# p2 player, money hand: MC player 75290.0 ('h', 5)('c', 9)
# after move 100000.0 340 -1
# reward 1
# j = 138 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 24910.0 ('h', 14)('d', 14)
# p2 player, money hand: MC player 75090.0 ('h', 6)('s', 9)
# after move 100000.0 -1 -1
# reward -1
# j = 139 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 24710.0 ('h', 3)('s', 11)
# p2 player, money hand: MC player 75290.0 ('d', 11)('d', 14)
# after move 100000.0 550 1900
# reward -1
# j = 140 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 23960.0 ('s', 7)('c', 12)
# p2 player, money hand: MC player 76040.0 ('h', 11)('h', 7)
# after move 100000.0 1040 -1
# reward 1
# j = 141 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 24160.0 ('d', 7)('d', 4)
# p2 player, money hand: MC player 75840.0 ('d', 6)('d', 11)
# after move 100000.0 1790 -1
# reward 1
# j = 142 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 24360.0 ('c', 9)('c', 11)
# p2 player, money hand: MC player 75640.0 ('h', 8)('s', 8)
# after move 100000.0 1210 0
# reward 0
# j = 143 winner is draw
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 24560.0 ('c', 11)('s', 14)
# p2 player, money hand: MC player 75440.0 ('d', 2)('s', 12)
# after move 100000.0 650 -1
# reward 1
# j = 144 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 24760.0 ('h', 11)('h', 14)
# p2 player, money hand: MC player 75240.0 ('d', 7)('s', 14)
# after move 100000.0 750 -1
# reward 1
# j = 145 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 24960.0 ('s', 13)('c', 2)
# p2 player, money hand: MC player 75040.0 ('h', 13)('d', 2)
# after move 100000.0 830 -1
# reward 1
# j = 146 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 25160.0 ('h', 12)('c', 10)
# p2 player, money hand: MC player 74840.0 ('s', 11)('c', 2)
# after move 100000.0 1600 -1
# reward 1
# j = 147 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 25360.0 ('s', 8)('c', 14)
# p2 player, money hand: MC player 74640.0 ('h', 12)('h', 4)
# after move 100000.0 950 -1
# reward 1
# j = 148 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 25560.0 ('c', 2)('h', 8)
# p2 player, money hand: MC player 74440.0 ('s', 14)('d', 10)
# after move 100000.0 -1 1620
# reward -1
# j = 149 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 24960.0 ('s', 13)('h', 8)
# p2 player, money hand: MC player 75040.0 ('d', 5)('d', 13)
# after move 100000.0 1050 -1
# reward 1
# j = 150 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 25160.0 ('s', 12)('c', 14)
# p2 player, money hand: MC player 74840.0 ('c', 5)('d', 8)
# after move 100000.0 1270 -1
# reward 1
# j = 151 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 25360.0 ('s', 10)('s', 3)
# p2 player, money hand: MC player 74640.0 ('h', 9)('d', 7)
# after move 100000.0 1840 -1
# reward 1
# j = 152 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 25560.0 ('d', 10)('h', 7)
# p2 player, money hand: MC player 74440.0 ('c', 3)('s', 10)
# after move 100000.0 1890 -1
# reward 1
# j = 153 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 25760.0 ('s', 7)('s', 14)
# p2 player, money hand: MC player 74240.0 ('c', 11)('s', 11)
# after move 100000.0 1580 2000
# reward -1
# j = 154 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 23980.0 ('c', 14)('d', 9)
# p2 player, money hand: MC player 76020.0 ('c', 6)('d', 5)
# after move 100000.0 1450 -1
# reward 1
# j = 155 winner is p1(Random Player)
#
# ...
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 2770.0 ('d', 9)('c', 8)
# p2 player, money hand: MC player 97230.0 ('d', 13)('c', 3)
# after move 100000.0 1340 -1
# reward 1
# j = 598 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 2970.0 ('h', 11)('h', 14)
# p2 player, money hand: MC player 97030.0 ('s', 12)('h', 7)
# after move 100000.0 1460 -1
# reward 1
# j = 599 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 3170.0 ('h', 10)('h', 9)
# p2 player, money hand: MC player 96830.0 ('d', 13)('s', 10)
# after move 100000.0 1370 0
# reward 1
# j = 600 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 5140.0 ('h', 13)('h', 14)
# p2 player, money hand: MC player 94860.0 ('s', 11)('d', 14)
# after move 100000.0 940 0
# reward 1
# j = 601 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 6680.0 ('d', 7)('c', 10)
# p2 player, money hand: MC player 93320.0 ('h', 13)('c', 4)
# after move 100000.0 1630 -1
# reward 1
# j = 602 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 6880.0 ('d', 7)('d', 13)
# p2 player, money hand: MC player 93120.0 ('h', 7)('h', 11)
# after move 100000.0 1660 -1
# reward 1
# j = 603 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 7080.0 ('s', 6)('h', 14)
# p2 player, money hand: MC player 92920.0 ('h', 3)('d', 3)
# after move 100000.0 1690 2000
# reward -1
# j = 604 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 5190.0 ('s', 9)('d', 7)
# p2 player, money hand: MC player 94810.0 ('c', 11)('h', 3)
# after move 100000.0 1810 -1
# reward 1
# j = 605 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 5390.0 ('h', 13)('c', 8)
# p2 player, money hand: MC player 94610.0 ('h', 12)('d', 5)
# after move 100000.0 1580 -1
# reward 1
# j = 606 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 5590.0 ('c', 14)('h', 6)
# p2 player, money hand: MC player 94410.0 ('h', 7)('c', 3)
# after move 100000.0 1480 -1
# reward 1
# j = 607 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 5790.0 ('c', 12)('d', 3)
# p2 player, money hand: MC player 94210.0 ('s', 7)('s', 8)
# after move 100000.0 1740 0
# reward -1
# j = 608 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 3850.0 ('h', 13)('h', 10)
# p2 player, money hand: MC player 96150.0 ('d', 5)('c', 5)
# after move 100000.0 1480 0
# reward 1
# j = 609 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 5930.0 ('s', 6)('s', 14)
# p2 player, money hand: MC player 94070.0 ('d', 4)('s', 12)
# after move 100000.0 1720 -1
# reward 1
# j = 610 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 6130.0 ('d', 9)('c', 6)
# p2 player, money hand: MC player 93870.0 ('d', 12)('c', 2)
# after move 100000.0 1010 -1
# reward 1
# j = 611 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 6330.0 ('h', 11)('d', 11)
# p2 player, money hand: MC player 93670.0 ('s', 12)('s', 6)
# after move 100000.0 510 -1
# reward 1
# j = 612 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 6530.0 ('s', 4)('h', 9)
# p2 player, money hand: MC player 93470.0 ('h', 13)('s', 7)
# after move 100000.0 530 -1
# reward 1
# j = 613 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 6730.0 ('c', 5)('d', 7)
# p2 player, money hand: MC player 93270.0 ('d', 11)('h', 14)
# after move 100000.0 810 0
# reward -1
# j = 614 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 5720.0 ('c', 8)('s', 3)
# p2 player, money hand: MC player 94280.0 ('d', 10)('h', 8)
# after move 100000.0 270 -1
# reward 1
# j = 615 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 5920.0 ('d', 7)('c', 8)
# p2 player, money hand: MC player 94080.0 ('d', 10)('c', 7)
# after move 100000.0 270 -1
# reward 1
# j = 616 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 6120.0 ('h', 8)('s', 7)
# p2 player, money hand: MC player 93880.0 ('h', 10)('c', 12)
# after move 100000.0 1650 2000
# reward -1
# j = 617 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 4270.0 ('c', 5)('d', 2)
# p2 player, money hand: MC player 95730.0 ('d', 12)('s', 4)
# after move 100000.0 1080 -1
# reward 1
# j = 618 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 4470.0 ('h', 10)('h', 4)
# p2 player, money hand: MC player 95530.0 ('c', 6)('s', 9)
# after move 100000.0 970 -1
# reward 1
# j = 619 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 4670.0 ('s', 12)('h', 9)
# p2 player, money hand: MC player 95330.0 ('c', 2)('c', 9)
# after move 100000.0 470 -1
# reward 1
# j = 620 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 4870.0 ('c', 12)('s', 9)
# p2 player, money hand: MC player 95130.0 ('h', 3)('h', 5)
# after move 100000.0 1500 -1
# reward 1
# j = 621 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 5070.0 ('s', 6)('h', 5)
# p2 player, money hand: MC player 94930.0 ('d', 6)('h', 9)
# after move 100000.0 910 -1
# reward 1
# j = 622 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 5270.0 ('s', 10)('d', 13)
# p2 player, money hand: MC player 94730.0 ('s', 13)('h', 10)
# after move 100000.0 1490 1990
# reward 0
# j = 623 winner is draw
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 5270.0 ('d', 7)('c', 2)
# p2 player, money hand: MC player 94730.0 ('s', 4)('h', 2)
# after move 100000.0 570 -1
# reward 1
# j = 624 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 5470.0 ('s', 6)('s', 2)
# p2 player, money hand: MC player 94530.0 ('h', 7)('c', 10)
# after move 100000.0 1760 -1
# reward 1
# j = 625 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 5670.0 ('d', 12)('h', 13)
# p2 player, money hand: MC player 94330.0 ('d', 4)('c', 9)
# after move 100000.0 880 -1
# reward 1
# j = 626 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 5870.0 ('c', 14)('c', 10)
# p2 player, money hand: MC player 94130.0 ('s', 11)('s', 8)
# after move 100000.0 1990 0
# reward 1
# j = 627 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 8460.0 ('s', 7)('c', 4)
# p2 player, money hand: MC player 91540.0 ('s', 13)('c', 13)
# after move 100000.0 830 0
# reward -1
# j = 628 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 7430.0 ('s', 12)('d', 8)
# p2 player, money hand: MC player 92570.0 ('s', 7)('d', 3)
# after move 100000.0 1620 -1
# reward 1
# j = 629 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 7630.0 ('d', 8)('s', 6)
# p2 player, money hand: MC player 92370.0 ('d', 14)('h', 2)
# after move 100000.0 1730 -1
# reward 1
# j = 630 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 7830.0 ('h', 4)('c', 5)
# p2 player, money hand: MC player 92170.0 ('h', 6)('d', 8)
# after move 100000.0 880 -1
# reward 1
# j = 631 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 8030.0 ('s', 4)('s', 3)
# p2 player, money hand: MC player 91970.0 ('c', 4)('d', 4)
# after move 100000.0 -1 1790
# reward -1
# j = 632 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 7390.0 ('c', 14)('h', 7)
# p2 player, money hand: MC player 92610.0 ('c', 2)('d', 7)
# after move 100000.0 1220 -1
# reward 1
# j = 633 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 7590.0 ('c', 13)('c', 3)
# p2 player, money hand: MC player 92410.0 ('d', 11)('c', 14)
# after move 100000.0 -1 1410
# reward -1
# j = 634 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 7110.0 ('s', 12)('s', 14)
# p2 player, money hand: MC player 92890.0 ('c', 3)('d', 5)
# after move 100000.0 230 -1
# reward 1
# j = 635 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 7310.0 ('d', 3)('h', 13)
# p2 player, money hand: MC player 92690.0 ('s', 5)('s', 10)
# after move 100000.0 840 -1
# reward 1
# j = 636 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 7510.0 ('s', 13)('c', 4)
# p2 player, money hand: MC player 92490.0 ('h', 4)('d', 2)
# after move 100000.0 1580 -1
# reward 1
# j = 637 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 7710.0 ('h', 2)('h', 13)
# p2 player, money hand: MC player 92290.0 ('c', 10)('d', 11)
# after move 100000.0 1600 0
# reward -1
# j = 638 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 5910.0 ('c', 7)('s', 7)
# p2 player, money hand: MC player 94090.0 ('d', 2)('s', 9)
# after move 100000.0 1330 -1
# reward 1
# j = 639 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 6110.0 ('c', 9)('d', 13)
# p2 player, money hand: MC player 93890.0 ('s', 11)('d', 12)
# after move 100000.0 1110 0
# reward -1
# j = 640 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 4800.0 ('d', 5)('h', 14)
# p2 player, money hand: MC player 95200.0 ('s', 10)('c', 9)
# after move 100000.0 1170 -1
# reward 1
# j = 641 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 5000.0 ('d', 3)('h', 12)
# p2 player, money hand: MC player 95000.0 ('c', 9)('c', 2)
# after move 100000.0 460 -1
# reward 1
# j = 642 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 5200.0 ('s', 13)('h', 13)
# p2 player, money hand: MC player 94800.0 ('d', 11)('c', 13)
# after move 100000.0 -1 1860
# reward -1
# j = 643 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 4480.0 ('h', 4)('c', 14)
# p2 player, money hand: MC player 95520.0 ('s', 14)('d', 14)
# after move 100000.0 1630 0
# reward -1
# j = 644 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 2650.0 ('c', 9)('c', 11)
# p2 player, money hand: MC player 97350.0 ('h', 2)('h', 4)
# after move 100000.0 1160 -1
# reward 1
# j = 645 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 2850.0 ('h', 3)('d', 7)
# p2 player, money hand: MC player 97150.0 ('h', 13)('c', 11)
# after move 100000.0 1520 2000
# reward -1
# j = 646 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 1130.0 ('h', 5)('c', 4)
# p2 player, money hand: MC player 98870.0 ('h', 10)('c', 11)
# after move 100000.0 1930 2000
# reward -1
# j = 647 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player -1000.0 ('c', 8)('s', 6)
# p2 player, money hand: MC player 101000.0 ('d', 14)('h', 4)
# Player Balance Under 0, End this Game.
#
# Good Game!
#
# 현재 라운드: 648
# Random Player 승리 횟수: 512 MC player 승리 횟수: 129 비긴 횟수: 7
# Random Player 잔고: -1000.0, MC player 잔고: 101000.0 잔고합계 100000.0
# 수행 시간: 19.311535596847534
