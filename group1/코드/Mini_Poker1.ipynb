# %%
import numpy   as np
import random
import copy

class Environment:
    #게임판 구성, 안되는 상태, 완료된 상태, 보상 정의,
    #게임판 핸드만 두장 줌, 베팅 한 번씩 물어봄. 리레이즈x

    # 덱을 만듬. 턴, 판돈, 플레이어가 베팅한 횟수 설정


    def __init__(self):
        self.done = False #True면 게임 종료
        #self.winner = 0
        self.reward = 0
        self.turn = 0
        self.table = 0
        self.player_calls =0
        self.lowlimit = 200
        self.maxlimit = 2000
        self.bet1 = -2
        self.bet2 = -2

        deck = [(suit, i) for suit in ["s", "h", "d", "c"] for i in range(2, 15)]  ##카드 덱 만들기, 튜플로 구성된 리스트
        random.shuffle(deck)
        self.deck = deck

    # 두 플레이어에게 분배할 네장을 뽑음
        #self.hands = [self.deck[0], self.deck[1], self.deck[2], self.deck[3]]

    # 보상을 정의  handcheck, ai_action은 agent가 준다.
    def pf_reward(self, handcheck, ai_action):
        print('hc, a', handcheck, ai_action)
        if (handcheck == 1) and (ai_action > 0):
            print('ai folded')
            # if ai_action >= 0:  # 콜, 레이즈, 체크
            rwd = -1
        elif (handcheck == 1) and (ai_action < 0):  # 폴드한 경우
            rwd = +1

        elif (handcheck != 1) and (ai_action > 0):
            # if ai_action >= 0:  # 콜, 레이즈, 체크
            rwd = +1
        else:  # 폴드한 경우
            rwd = -1

        return rwd

    def move(self, p1,p2): #, player):
        #각플레이어가 선택한 행동 table에 반영하고 게임 상태 판단
        #p1 = 1, p2 = -1
        #각 플레이어는 행동을 선택하는 메서드를 가짐 selct_action
        #if player == 1:
        self.bet1 = p1.select_action(env)#, player)
        if self.bet1 == -1: #폴드한 경우
          pass
        else:
          self.table += self.bet1
        self.player_calls += 1
        #else:
        self.bet2 = p2.select_action(env)#, player)
        if self.bet2 > self.lowlimit: #리레이즈시
          self.table += self.bet2
          self.bet1 = p1.select_action(env)#, player) # 한번 더 행동을 받음
          if self.bet1 == -1:
            pass
          else:
            self.table += self.bet1
          self.player_calls += 1
        else:
          if self.bet2 == -1:
            pass
          else:
            self.table += self.bet2
          self.player_calls += 1

         
        #self.table += bet1 +bet2
        #print('table: ',self.table)
        #게임 상태가 종료인지 판단, 누가 이겼는지 체크
      
        self.end_check(p1,p2)
        self.player_calls =0
        return self.reward, self.done

    #현재 베팅 가능한 상태 수집.
    def get_action(self):
        observation = [-1,0]
        #table이 0이 아니다. -> 누군가 베팅을 했다면 lowlimit 이 그 두배로 바뀜
        #print('테이블 상황:', self.table)
        if self.table > 0:
          if self.table*2 > 2000:
            self.lowlimit = 2000
          else:
            self.lowlimit =  self.table*2
        #print('로우리밋 상황', self.lowlimit)
        for i in range(self.lowlimit, self.maxlimit+1):
            observation.append(i)
        return observation

    #게임 종료 판단
    def end_check(self, p1,p2):
        if self.player_calls == 2:
            # 1. agent 가 player보다 카드가 좋다.
            #판돈에 플레이어의 베팅을 반영 및 표시
            if (self.bet1 == -1): #누군가 폴드하면 상대가 
              p2.bal += self.table
              #p1.bal -= 1
              self.table = 0
              self.reward = -1 # 승자는 p2
              self.done = True
              #self.player_calls =0
            elif (self.bet2 == -1): # 누군가 폴드한 경우
              p1.bal += self.table
              #p2.bal -= 1
              self.table = 0
              self.reward = 1 #승자는 p1
              self.done = True
              
              #self.player_calls =0
            else:
              #print('winner checking', p1.hand1, p1.hand2, p2.hand1, p2.hand2)
              #print(self.hand_check(p1.hand1, p1.hand2))
              #print(self.hand_check(p2.hand1, p2.hand2))
              #print(self.bet1, self.bet2)
              if self.hand_check(p1.hand1, p1.hand2) > self.hand_check(p2.hand1, p2.hand2):
                  self.reward = 1
                  p1.bal += self.table  # 테이블의 돈을 가져감
                  self.table = 0
                  self.done = True
              # 2. agent 가 player보다 카드가 안 좋다.
              elif self.hand_check(p1.hand1, p1.hand2) < self.hand_check(p2.hand1, p2.hand2):
                  self.reward = -1
                  p2.bal += self.table  # 테이블의 돈을 가져감
                  self.table = 0
                  self.done = True
              # 3. agent 가 player보다 카드가 같다. -> 무승부 판돈 분할
              else:
                  self.reward = 0
                  p1.bal += self.table/2
                  p2.bal += self.table/2
                  self.table = 0
                  self.done = True # 돈은 그대로 남아있음.
        else:
            pass
        return

    def print_poker(self, player):
        print('\n------------------Turn : %d-------------------\n'%self.turn)
        print('Table Money: %d'%self.table)
        print('Now Bet: %s'%player.name)

    # 핸드 순위 확인
    def hand_check(self, hand1, hand2):  # 핸드체크, 프레플랍 단계 먼저 자신에게 주어진 카드 정보를 분석한다.
        premium = [('p', 14, 14), ('p', 13, 13), ('p', 12, 12), ('s', 14, 13), ('p', 11, 11), ('s', 14, 12),
                   ('s', 13, 12), ('s', 14, 11), ('s', 13, 11), ('p', 10, 10), ('o', 14, 13), ('s', 14, 10),
                   ('s', 12, 11), ('s', 13, 10), ('s', 12, 10), ('s', 11, 10), ('p', 9, 9)]
        special = [('o', 14, 12), ('s', 14, 9), ('o', 13, 12), ('p', 8, 8), ('s', 13, 9), ('s', 10, 9),
                   ('s', 14, 8),
                   ('s', 12, 9), ('s', 11, 9), ('o', 14, 11), ('s', 14, 5), ('p', 7, 7), ('s', 14, 7),
                   ('o', 13, 11),
                   ('s', 14, 4), ('s', 14, 3), ('s', 14, 6)]
        good = [('o', 12, 11), ('p', 6, 6), ('s', 13, 8), ('s', 10, 8), ('s', 14, 2), ('s', 9, 8), ('s', 11, 8),
                ('o', 14, 10), ('s', 12, 8), ('s', 13, 7), ('o', 13, 10), ('p', 5, 5), ('o', 11, 10), ('s', 8, 7),
                ('o', 12, 10), ('p', 4, 4), ('p', 3, 3), ('p', 2, 2)]
        # 숫자 비교 후 pair인지 확인(pair이면 p, 아니면 문자 확인으로 넘어감), 문자 확인해서 일치하는지 확인(불일치 하면 o, 일치하면 s ),  숫자 조합해서 하나의 튜플로 제작
        if hand1[1] == hand2[1]:
            tup1 = 'p'
        else:
            if hand1[0] == hand2[0]:
                tup1 = 's'
            else:
                tup1 = 'o'

        if hand1[1] > hand2[1]:  # 숫자 큰 게 앞으로 오게 함
            tup2, tup3 = hand1[1], hand2[1]
        else:
            tup2, tup3 = hand2[1], hand1[1]

        tup = (tup1, tup2, tup3)  # 튜플 생성
        #print('tup', tup)
        if premium.count(tup) == 1:
            return 4  # ('premium')
        elif special.count(tup) == 1:
            return 3  # ('special')
        elif good.count(tup) == 1:  # 판단
            return 2  # ('good')
        else:
            return 1  # ('fold')

'''        
    # 에이전트의 행동 결과 반환 
    def move(self, agent, player, ai_action, player_action):
        # 에이전트가 선택한 행동 결과 반환
        관찰: 선택한 행동에 의해 발생한 에이전트의 잔고 변화
            보상: 행동에 따른 보상 
            완료: True면 에피소드 끝냄, False면 계속 진행, 모든 단계가 끝났으면 True
        
        
        # 행동에 따른 판돈 구하기 
        self.table = self.table + agent.action[ai_action]
        
        # 에이전트가 베팅 시도를 했다면
        if agent.action:
            reward = self.pf_reward(self.hand_check(agent.h1, agent.h2), ai_action)
            observation = agent.bal_cal(agent.bal)            
            self.player_calls += 1

        # 모든 플레이어의 베팅이 완료 됐음
        if self.player_calls == 2:
            self.winner(self, agent, player)
            done = True
        # 베팅이 완료되지 않았다면, 끝나지 않음
        else:
            pass
        
        return reward, observation, done
'''




class Human_player:
    
    
    def __init__(self):
        self.name = 'Human Player'
        self.bal = 50000
        self.hand1 = 0
        self.hand2 = 0
    
    
    def select_action(self, env):#,player):
        while True:
            available_action = env.get_action()
            if (env.bet1 > 0) and (env.bet2> 2*env.bet1): #리레이즈의 상황이라면 
              available_action = [-1, env.bet2-env.bet1] #폴드하거나 콜만 함
            print("possible actions = {}".format(available_action))
            print("{} Hands: {}{}".format(self.name, self.hand1, self.hand2))
            action = int(input(f"Select action(human)(fold == -1, call/check = 0 , {env.lowlimit} <= raise<= {env.maxlimit}  : "))
            if action in available_action:
              if action == 0: # 콜/체크라면 상대가 제시한 만큼 내게 됨. 추후 라운드 추가시 변경
                self.bal -= env.table
                env.table += env.table 
              self.bal -= action
              return action
            else:
                print("Wrong Action. Try Again")
        return

class Random_player:
    
    def __init__(self):
        self.name = 'Random Player'
        self.bal = 50000
        self.hand1 = 0
        self.hand2 = 0

    def select_action(self, env):

        available_action = env.get_action()
        if (env.bet1 > 0) and (env.bet2> 2*env.bet1): #리레이즈의 상황이라면 
          available_action = [-1, env.bet2-env.bet1] #폴드하거나 콜만 함
        #print("possible actions = {}".format(available_action))
        #print("{} Hands: {}{}".format(self.name, self.hand1, self.hand2))
        action = random.choice(available_action)
        #print(action)
        if action == 0: # 콜/체크라면 상대가 제시한 만큼 내게 됨. 추후 라운드 추가시 변경
          self.bal -= env.table
          env.table += env.table
        if action == -1:
          pass
        else:
          self.bal -= action
        return action

class Monte_Carlo_player:
  def __init__(self):
    self.name = "MC player"
    self.num_playout = 1
    self.bal = 50000
    self.hand1 = 0
    self.hand2 = 0
    

  def select_action(self, env):#, player)
    #print('MC select_action, 실제선택')
    #가능한 행동 조사
    available_action = env.get_action()
    if (env.bet1 > 0) and (env.bet2> 2*env.bet1): #리레이즈의 상황이라면 
      available_action = [-1, env.bet2-env.bet1] #폴드하거나 콜만 함
    V = np.zeros(len(available_action))
    #print(V)
    #input() 
    temp_p1 = Random_player()
    temp_p1.hand1 = p1.hand1
    temp_p1.hand2 = p1.hand2
    temp_p1.bal = p1.bal
    temp_p2 = Random_player()
    temp_p2.hand1 = p2.hand1
    temp_p2.hand2 = p2.hand2
    temp_p2.bal = p2.bal
    #print('available_action길이', len(available_action))
    #print('실제 가능한 액션',available_action)
    for i in range(len(available_action)):

      #플레이아웃을 1000번 반복
      for j in range(self.num_playout):

        #지금 상태를 복사해서 블레이 아웃에 사용
        temp_env = copy.deepcopy(env)
        #플레이 아웃의 결과는 승리 플레이어의 값으로 반환
        #p1이 이기면 1 p2가 이기면 -1
        #print(available_action[i])# , player)
        #print(V)
        #input()
        self.playout(temp_env, available_action[i], temp_p1, temp_p2)#, player)
        #print('리워드 누구냐', temp_env.reward, j)
        #print(temp_env.table)
        #temp_table = copy.copy(temp_env.table)
        if 1 == temp_env.reward:
          V[i] += i#temp_env.lowlimit#available_action[i]#i#1#temp_env.bet2
          #print(V)
          #input()
    #print('실제 가능한 액션, 가치함수 V, np.argmax(V)',available_action, V, np.argmax(V))
    action = available_action[np.argmax(V)]
    if action == 0: # 콜/체크라면 상대가 제시한 만큼 내게 됨. 추후 라운드 추가시 변경
          self.bal -= env.table
          env.table += env.table
    if action == -1:
      pass
    else:
      self.bal -= action
    return action

  #플레이아웃 재귀 함수
  # 게임이 종료 상태(승/패/비김)가 될 때까지 행동을 임의로 선택하는 것을 반복
  #플레이어는 계속 바뀌기 때문에 (-)를 곱해서 -1, 1 ,-1 순서로 변하게 함
  def playout(self, temp_env, action,temp_p1, temp_p2):#, player):
    #판돈에 플레이어의 베팅을 반영 및 표시
    #print('playout start: action =', action)
    temp_env.bet1 = action
    temp_env.table += temp_env.bet1
    temp_env.player_calls += 1
    
    #print(temp_env.table, temp_env.reward)
     #게임 종료 체크 
    if temp_env.player_calls == 2:
      #temp_env.done = True
      #print('playout end_check')
      temp_env.end_check(temp_p1, temp_p2)
      temp_env.player_calls =0
      #print(available_action)
      return #player

    else:
      # vmffpdldj rycp
      #player = -player
      #가능한 행동 조사 
      #available_action = temp_env.get_action()
      #print('available_action', available_action)
      #a무작위로 행동을 선택
      #action = random.choice(available_action)
      #print(action)
      #self.playout(temp_env, action, player)
      temp_env.bet2 = temp_p2.select_action(temp_env)
      temp_env.table += temp_env.bet2
      temp_env.player_calls += 1


#p1 = Monte_Carlo_player()
p1 = Random_player()
#p1 = Human_player()
#p2 = Human_player()
#p2 = Random_player()
p2 = Monte_Carlo_player()
# 지정된 게임 수를 자동으로 두게 할 것인지 한 게임씩 두게 할 것인지 결정
# auto = True : 지정된 판 수 (games)를 자동으로 진행
# auto = Flase: 한 게임씩 진행
auto = True

#auto 모드의 게임 수
games = 1000
#print("p1 player, money : {}{}".format(p1.name, p1.bal))
#print("p2 player, money : {}{}".format(p1.name, p2.bal))

#각 플레이어의 승리 횟수를 저장
p1_score = 0
p2_score = 0
draw_score = 0

if auto:

    #자동모드 실행
    for j in range(games):
        np.random.seed(j)
        env = Environment()
        p1.hand1, p1.hand2 = env.deck.pop(), env.deck.pop()
        p2.hand1, p2.hand2 = env.deck.pop(), env.deck.pop()
        print('\n------------------------------------------------------------------------------------------------------------------')
        print("p1 player, money, hand : {} {} {}{}".format(p1.name, p1.bal, p1.hand1, p1.hand2))
        print("p2 player, money hand: {} {} {}{}".format(p2.name, p2.bal, p2.hand1, p2.hand2))
        
        if (p1.bal < 0) or (p2.bal <0):
          print('Player Balance Under 0, End this Game.\n')
          break
        for i in range(10000):
            # p1, p2 번갈아가면서 게임을 진행
            # p1(1) -> p2(-1)
            sum = p1.bal+p2.bal
            #print(p1.bal, p2.bal)
            #print('before move',sum, env.bet1, env.bet2)
            reward, done = env.move(p1,p2) #,(-1)**i)
            print('after move',sum, env.bet1, env.bet2)
            if sum != 100000:
              print('after move',sum, env.bet1, env.bet2)
              input()
            print('reward', reward)
            # 게임 종료 체크
            if done == True:
                if reward == 1:
                    print("j = {} winner is p1({})".format(j, p1.name))
                    p1_score += 1
                elif reward == -1:
                    print("j = {} winner is p2({})".format(j, p2.name))
                    p2_score += 1
                else:
                    print("j = {} winner is draw".format(j))
                    draw_score += 1
                break
    print("\ntable= {} p1({}) = {} p2({}) = {} draw = {}".format(env.table, p1.name, p1_score, p2.name, p2_score, draw_score))
    print("p1.bal= {} p2.bal={} sum = {}".format(p1.bal, p2.bal, p1.bal+p2.bal))

else:
    #한 게임씩 진행하는 수동 모드
    while True:
        #env = Environment()
        env = Environment()
        p1.hand1, p1.hand2 = env.deck.pop(), env.deck.pop()
        p2.hand1, p2.hand2 = env.deck.pop(), env.deck.pop()
        print('------------------------------------------------------------------------------------------------------------------')
        print("p1 player, money, hand : {} {} {}{}".format(p1.name, p1.bal, p1.hand1, p1.hand2))
        print("p2 player, money hand: {} {} {}{}".format(p1.name, p2.bal, p2.hand1, p2.hand2))
        #print('------------------------------------------------------------------------------------------------------------------')
        #env.print = True

        for i in range(10000):
            # p1, p2 번갈아가면서 게임을 진행
            # p1(1) -> p2(-1)
            reward, done = env.move(p1, p2, (-1)**i)
            print('reward', reward)
            # 게임 종료 체크
            if done == True:
                if reward == 1:
                    print("Winner is p1({})".format(p1.name))
                    p1_score += 1
                elif reward == -1:
                    print("Winner is p2({})".format(p2.name))
                    p2_score += 1
                else:
                    print("No Winner")
                    draw_score += 1
                break

        print("final result")
        env.print_poker(p1)

        print("final result")
        env.print_poker(p2)

        # one more?
        answer = input("more Game? (y/n)")
        print("table= {} p1({}) = {} p2({}) = {} draw = {}".format(env.table, p1.name, p1_score, p2.name, p2_score, draw_score))
        if answer == 'y':
            pass
        else:
            break
# Out:
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 50000 ('h', 3)('d', 13)
# p2 player, money hand: MC player 50000 ('c', 5)('c', 6)
# after move 100000 367 -1
# reward 1
# j = 0 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 50000 ('s', 12)('d', 4)
# p2 player, money hand: MC player 50000 ('d', 14)('h', 13)
# after move 100000 1283 -1
# reward 1
# j = 1 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 50000 ('c', 6)('c', 14)
# p2 player, money hand: MC player 50000 ('s', 12)('s', 6)
# after move 100000 -1 2000
# reward -1
# j = 2 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 49598 ('h', 13)('s', 6)
# p2 player, money hand: MC player 50402 ('h', 11)('s', 12)
# after move 100000 1907 -1
# reward 1
# j = 3 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 49598 ('d', 13)('d', 6)
# p2 player, money hand: MC player 50402 ('h', 7)('h', 12)
# after move 100000 1511 -1
# reward 1
# j = 4 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 49598 ('d', 10)('h', 8)
# p2 player, money hand: MC player 50402 ('s', 2)('h', 10)
# after move 100000 1270 -1
# reward 1
# j = 5 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 49598 ('s', 11)('s', 14)
# p2 player, money hand: MC player 50402 ('d', 9)('c', 5)
# after move 100000 1616 2000
# reward 1
# j = 6 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 51598 ('h', 10)('d', 7)
# p2 player, money hand: MC player 48402 ('c', 11)('d', 3)
# after move 100000 1204 -1
# reward 1
# j = 7 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 51598 ('s', 10)('s', 13)
# p2 player, money hand: MC player 48402 ('s', 2)('c', 3)
# after move 100000 1098 2000
# reward 1
# j = 8 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 53598 ('d', 4)('h', 8)
# p2 player, money hand: MC player 46402 ('c', 3)('d', 13)
# after move 100000 390 -1
# reward 1
# j = 9 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 53598 ('h', 2)('s', 6)
# p2 player, money hand: MC player 46402 ('h', 11)('d', 8)
# after move 100000 1599 -1
# reward 1
# j = 10 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 53598 ('s', 14)('s', 13)
# p2 player, money hand: MC player 46402 ('d', 2)('c', 11)
# after move 100000 1787 2000
# reward 1
# j = 11 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 55598 ('h', 7)('c', 14)
# p2 player, money hand: MC player 44402 ('h', 5)('s', 7)
# after move 100000 517 -1
# reward 1
# j = 12 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 55598 ('s', 8)('c', 14)
# p2 player, money hand: MC player 44402 ('s', 6)('h', 6)
# after move 100000 257 -1
# reward 1
# j = 13 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 55598 ('c', 6)('d', 7)
# p2 player, money hand: MC player 44402 ('d', 9)('s', 3)
# after move 100000 1798 -1
# reward 1
# j = 14 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 55598 ('d', 2)('d', 7)
# p2 player, money hand: MC player 44402 ('h', 11)('h', 10)
# after move 100000 1283 -1
# reward 1
# j = 15 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 55598 ('c', 3)('c', 10)
# p2 player, money hand: MC player 44402 ('h', 5)('c', 13)
# after move 100000 687 -1
# reward 1
# j = 16 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 55598 ('h', 12)('d', 14)
# p2 player, money hand: MC player 44402 ('h', 8)('d', 6)
# after move 100000 -1 2000
# reward -1
# j = 17 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 54759 ('d', 3)('d', 4)
# p2 player, money hand: MC player 45241 ('d', 14)('c', 5)
# after move 100000 442 -1
# reward 1
# j = 18 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 54759 ('d', 2)('c', 7)
# p2 player, money hand: MC player 45241 ('c', 10)('d', 11)
# after move 100000 379 -1
# reward 1
# j = 19 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 54759 ('h', 4)('h', 3)
# p2 player, money hand: MC player 45241 ('s', 14)('d', 12)
# after move 100000 1315 -1
# reward 1
# j = 20 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 54759 ('c', 14)('d', 14)
# p2 player, money hand: MC player 45241 ('s', 4)('c', 12)
# after move 100000 1027 2000
# reward 1
# j = 21 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 56759 ('c', 13)('d', 3)
# p2 player, money hand: MC player 43241 ('h', 3)('s', 9)
# after move 100000 1193 -1
# reward 1
# j = 22 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 56759 ('d', 13)('d', 3)
# p2 player, money hand: MC player 43241 ('c', 10)('c', 6)
# after move 100000 524 -1
# reward 1
# j = 23 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 56759 ('s', 12)('c', 13)
# p2 player, money hand: MC player 43241 ('c', 5)('s', 10)
# after move 100000 1717 2000
# reward 1
# j = 24 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 58759 ('s', 2)('c', 9)
# p2 player, money hand: MC player 41241 ('d', 7)('s', 9)
# after move 100000 1387 -1
# reward 1
# j = 25 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 58759 ('c', 8)('s', 12)
# p2 player, money hand: MC player 41241 ('d', 2)('c', 4)
# after move 100000 1319 -1
# reward 1
# j = 26 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 58759 ('h', 6)('s', 11)
# p2 player, money hand: MC player 41241 ('c', 7)('s', 6)
# after move 100000 264 -1
# reward 1
# j = 27 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 58759 ('c', 13)('s', 8)
# p2 player, money hand: MC player 41241 ('d', 12)('s', 6)
# after move 100000 805 -1
# reward 1
# j = 28 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 58759 ('s', 5)('c', 12)
# p2 player, money hand: MC player 41241 ('h', 11)('h', 3)
# after move 100000 549 -1
# reward 1
# j = 29 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 58759 ('d', 5)('c', 13)
# p2 player, money hand: MC player 41241 ('h', 14)('s', 10)
# after move 100000 1056 -1
# reward 1
# j = 30 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 58759 ('s', 12)('h', 3)
# p2 player, money hand: MC player 41241 ('h', 2)('c', 14)
# after move 100000 1260 -1
# reward 1
# j = 31 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 58759 ('s', 13)('c', 9)
# p2 player, money hand: MC player 41241 ('h', 5)('d', 14)
# after move 100000 1960 -1
# reward 1
# j = 32 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 58759 ('s', 8)('s', 2)
# p2 player, money hand: MC player 41241 ('s', 3)('d', 12)
# after move 100000 975 -1
# reward 1
# j = 33 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 58759 ('h', 14)('h', 2)
# p2 player, money hand: MC player 41241 ('d', 12)('c', 9)
# after move 100000 1364 2000
# reward 1
# j = 34 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 60759 ('d', 8)('s', 13)
# p2 player, money hand: MC player 39241 ('s', 5)('d', 11)
# after move 100000 991 -1
# reward 1
# j = 35 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 60759 ('h', 11)('h', 6)
# p2 player, money hand: MC player 39241 ('h', 12)('d', 9)
# after move 100000 1594 -1
# reward 1
# j = 36 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 60759 ('d', 9)('c', 3)
# p2 player, money hand: MC player 39241 ('h', 7)('s', 12)
# after move 100000 1323 -1
# reward 1
# j = 37 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 60759 ('c', 2)('h', 8)
# p2 player, money hand: MC player 39241 ('d', 12)('s', 5)
# after move 100000 1792 -1
# reward 1
# j = 38 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 60759 ('s', 2)('s', 3)
# p2 player, money hand: MC player 39241 ('d', 5)('h', 10)
# after move 100000 1224 -1
# reward 1
# j = 39 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 60759 ('d', 2)('h', 10)
# p2 player, money hand: MC player 39241 ('c', 8)('h', 5)
# after move 100000 1772 -1
# reward 1
# j = 40 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 60759 ('d', 12)('d', 13)
# p2 player, money hand: MC player 39241 ('s', 13)('h', 11)
# after move 100000 1083 2000
# reward 1
# j = 41 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 62759 ('h', 10)('c', 9)
# p2 player, money hand: MC player 37241 ('d', 13)('d', 9)
# after move 100000 383 -1
# reward 1
# j = 42 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 62759 ('s', 10)('c', 3)
# p2 player, money hand: MC player 37241 ('h', 8)('h', 12)
# after move 100000 504 -1
# reward 1
# j = 43 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 62759 ('s', 10)('c', 7)
# p2 player, money hand: MC player 37241 ('c', 9)('s', 11)
# after move 100000 686 -1
# reward 1
# j = 44 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 62759 ('s', 10)('d', 7)
# p2 player, money hand: MC player 37241 ('c', 5)('h', 11)
# after move 100000 800 -1
# reward 1
# j = 45 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 62759 ('s', 13)('c', 3)
# p2 player, money hand: MC player 37241 ('h', 6)('d', 6)
# after move 100000 485 -1
# reward 1
# j = 46 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 62759 ('c', 13)('s', 13)
# p2 player, money hand: MC player 37241 ('d', 2)('c', 14)
# after move 100000 1669 2000
# reward 1
# j = 47 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 64759 ('c', 5)('d', 13)
# p2 player, money hand: MC player 35241 ('s', 10)('s', 9)
# after move 100000 1506 -1
# reward 1
# j = 48 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 64759 ('c', 8)('d', 13)
# p2 player, money hand: MC player 35241 ('h', 10)('d', 8)
# after move 100000 514 -1
# reward 1
# j = 49 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 64759 ('s', 2)('s', 10)
# p2 player, money hand: MC player 35241 ('d', 13)('d', 5)
# after move 100000 417 -1
# reward 1
# j = 50 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 64759 ('s', 11)('c', 9)
# p2 player, money hand: MC player 35241 ('d', 5)('d', 3)
# after move 100000 1363 -1
# reward 1
# j = 51 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 64759 ('c', 14)('h', 2)
# p2 player, money hand: MC player 35241 ('s', 10)('d', 4)
# after move 100000 978 -1
# reward 1
# j = 52 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 64759 ('d', 8)('c', 4)
# p2 player, money hand: MC player 35241 ('d', 4)('h', 7)
# after move 100000 805 -1
# reward 1
# j = 53 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 64759 ('h', 5)('c', 12)
# p2 player, money hand: MC player 35241 ('c', 4)('h', 8)
# after move 100000 268 -1
# reward 1
# j = 54 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 64759 ('h', 6)('c', 9)
# p2 player, money hand: MC player 35241 ('s', 9)('d', 6)
# after move 100000 1646 -1
# reward 1
# j = 55 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 64759 ('s', 5)('c', 14)
# p2 player, money hand: MC player 35241 ('s', 6)('d', 13)
# after move 100000 723 -1
# reward 1
# j = 56 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 64759 ('s', 8)('h', 7)
# p2 player, money hand: MC player 35241 ('s', 2)('s', 14)
# after move 100000 1156 -1
# reward 1
# j = 57 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 64759 ('c', 7)('s', 9)
# p2 player, money hand: MC player 35241 ('c', 5)('c', 4)
# after move 100000 734 -1
# reward 1
# j = 58 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 64759 ('c', 10)('h', 2)
# p2 player, money hand: MC player 35241 ('h', 11)('c', 5)
# after move 100000 1852 -1
# reward 1
# j = 59 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 64759 ('c', 8)('h', 2)
# p2 player, money hand: MC player 35241 ('c', 9)('s', 2)
# after move 100000 1164 -1
# reward 1
# j = 60 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 64759 ('d', 5)('h', 11)
# p2 player, money hand: MC player 35241 ('c', 3)('c', 5)
# after move 100000 604 -1
# reward 1
# j = 61 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 64759 ('h', 6)('s', 9)
# p2 player, money hand: MC player 35241 ('s', 8)('h', 14)
# after move 100000 1662 -1
# reward 1
# j = 62 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 64759 ('d', 12)('c', 11)
# p2 player, money hand: MC player 35241 ('c', 10)('s', 6)
# after move 100000 1458 2000
# reward 1
# j = 63 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 66759 ('d', 11)('c', 12)
# p2 player, money hand: MC player 33241 ('h', 6)('s', 4)
# after move 100000 1262 2000
# reward 1
# j = 64 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 68759 ('c', 9)('c', 14)
# p2 player, money hand: MC player 31241 ('s', 4)('h', 5)
# after move 100000 1928 2000
# reward 1
# j = 65 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 70759 ('d', 12)('c', 13)
# p2 player, money hand: MC player 29241 ('h', 4)('h', 3)
# after move 100000 1955 2000
# reward 1
# j = 66 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 72759 ('s', 5)('h', 10)
# p2 player, money hand: MC player 27241 ('d', 7)('h', 8)
# after move 100000 707 -1
# reward 1
# j = 67 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 72759 ('c', 13)('h', 11)
# p2 player, money hand: MC player 27241 ('h', 6)('h', 10)
# after move 100000 -1 2000
# reward -1
# j = 68 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 72127 ('c', 10)('c', 3)
# p2 player, money hand: MC player 27873 ('d', 7)('h', 13)
# after move 100000 1466 -1
# reward 1
# j = 69 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 72127 ('s', 14)('d', 4)
# p2 player, money hand: MC player 27873 ('d', 7)('c', 6)
# after move 100000 485 -1
# reward 1
# j = 70 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 72127 ('s', 4)('h', 11)
# p2 player, money hand: MC player 27873 ('s', 8)('s', 7)
# after move 100000 1825 -1
# reward 1
# j = 71 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 72127 ('h', 2)('d', 5)
# p2 player, money hand: MC player 27873 ('h', 7)('c', 14)
# after move 100000 1395 -1
# reward 1
# j = 72 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 72127 ('s', 9)('c', 11)
# p2 player, money hand: MC player 27873 ('c', 7)('s', 3)
# after move 100000 363 -1
# reward 1
# j = 73 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 72127 ('c', 10)('c', 12)
# p2 player, money hand: MC player 27873 ('h', 3)('d', 5)
# after move 100000 -1 2000
# reward -1
# j = 74 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 71577 ('d', 6)('c', 14)
# p2 player, money hand: MC player 28423 ('d', 8)('c', 11)
# after move 100000 1378 -1
# reward 1
# j = 75 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 71577 ('s', 4)('s', 9)
# p2 player, money hand: MC player 28423 ('s', 3)('c', 12)
# after move 100000 1364 -1
# reward 1
# j = 76 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 71577 ('h', 13)('d', 11)
# p2 player, money hand: MC player 28423 ('c', 2)('d', 7)
# after move 100000 1902 2000
# reward 1
# j = 77 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 73577 ('h', 13)('s', 8)
# p2 player, money hand: MC player 26423 ('h', 7)('s', 3)
# after move 100000 1056 -1
# reward 1
# j = 78 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 73577 ('h', 7)('h', 13)
# p2 player, money hand: MC player 26423 ('c', 10)('d', 12)
# after move 100000 1836 -1
# reward 1
# j = 79 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 73577 ('s', 12)('h', 5)
# p2 player, money hand: MC player 26423 ('h', 6)('h', 9)
# after move 100000 387 -1
# reward 1
# j = 80 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 73577 ('c', 7)('d', 9)
# p2 player, money hand: MC player 26423 ('c', 10)('s', 11)
# after move 100000 940 -1
# reward 1
# j = 81 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 73577 ('s', 11)('s', 7)
# p2 player, money hand: MC player 26423 ('h', 12)('c', 10)
# after move 100000 1782 -1
# reward 1
# j = 82 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 73577 ('d', 14)('h', 10)
# p2 player, money hand: MC player 26423 ('d', 2)('c', 7)
# after move 100000 1906 2000
# reward 1
# j = 83 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 75577 ('c', 4)('d', 9)
# p2 player, money hand: MC player 24423 ('c', 14)('c', 6)
# after move 100000 411 -1
# reward 1
# j = 84 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 75577 ('c', 7)('h', 3)
# p2 player, money hand: MC player 24423 ('h', 10)('h', 4)
# after move 100000 519 -1
# reward 1
# j = 85 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 75577 ('s', 6)('d', 14)
# p2 player, money hand: MC player 24423 ('h', 5)('c', 11)
# after move 100000 405 -1
# reward 1
# j = 86 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 75577 ('h', 4)('c', 2)
# p2 player, money hand: MC player 24423 ('c', 10)('h', 10)
# after move 100000 1029 -1
# reward 1
# j = 87 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 75577 ('d', 2)('s', 9)
# p2 player, money hand: MC player 24423 ('h', 12)('c', 13)
# after move 100000 1272 -1
# reward 1
# j = 88 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 75577 ('s', 4)('h', 11)
# p2 player, money hand: MC player 24423 ('c', 5)('c', 13)
# after move 100000 417 -1
# reward 1
# j = 89 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 75577 ('h', 2)('c', 9)
# p2 player, money hand: MC player 24423 ('d', 14)('d', 4)
# after move 100000 1065 -1
# reward 1
# j = 90 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 75577 ('s', 2)('c', 3)
# p2 player, money hand: MC player 24423 ('d', 12)('h', 4)
# after move 100000 317 -1
# reward 1
# j = 91 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 75577 ('c', 10)('s', 12)
# p2 player, money hand: MC player 24423 ('c', 14)('h', 8)
# after move 100000 -1 2000
# reward -1
# j = 92 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 75287 ('c', 2)('s', 11)
# p2 player, money hand: MC player 24713 ('d', 3)('h', 13)
# after move 100000 526 -1
# reward 1
# j = 93 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 75287 ('s', 10)('h', 14)
# p2 player, money hand: MC player 24713 ('h', 11)('c', 7)
# after move 100000 1843 2000
# reward 1
# j = 94 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 77287 ('s', 9)('s', 7)
# p2 player, money hand: MC player 22713 ('h', 4)('s', 8)
# after move 100000 382 -1
# reward 1
# j = 95 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 77287 ('c', 12)('c', 14)
# p2 player, money hand: MC player 22713 ('h', 14)('d', 8)
# after move 100000 1522 2000
# reward 1
# j = 96 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 79287 ('c', 4)('h', 7)
# p2 player, money hand: MC player 20713 ('h', 8)('d', 7)
# after move 100000 1909 -1
# reward 1
# j = 97 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 79287 ('c', 8)('s', 9)
# p2 player, money hand: MC player 20713 ('d', 13)('s', 5)
# after move 100000 1663 -1
# reward 1
# j = 98 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 79287 ('c', 5)('s', 13)
# p2 player, money hand: MC player 20713 ('d', 9)('c', 2)
# after move 100000 1919 -1
# reward 1
# j = 99 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 79287 ('d', 8)('s', 2)
# p2 player, money hand: MC player 20713 ('s', 4)('h', 7)
# after move 100000 1040 -1
# reward 1
# j = 100 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 79287 ('s', 9)('h', 2)
# p2 player, money hand: MC player 20713 ('s', 5)('h', 8)
# after move 100000 1442 -1
# reward 1
# j = 101 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 79287 ('c', 6)('h', 8)
# p2 player, money hand: MC player 20713 ('s', 12)('c', 7)
# after move 100000 1466 -1
# reward 1
# j = 102 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 79287 ('s', 14)('d', 13)
# p2 player, money hand: MC player 20713 ('h', 10)('s', 2)
# after move 100000 -1 2000
# reward -1
# j = 103 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 78472 ('d', 11)('h', 12)
# p2 player, money hand: MC player 21528 ('h', 2)('c', 14)
# after move 100000 1705 2000
# reward 1
# j = 104 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 80472 ('c', 13)('c', 2)
# p2 player, money hand: MC player 19528 ('d', 7)('s', 12)
# after move 100000 1816 -1
# reward 1
# j = 105 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 80472 ('c', 5)('c', 2)
# p2 player, money hand: MC player 19528 ('h', 6)('h', 7)
# after move 100000 260 -1
# reward 1
# j = 106 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 80472 ('h', 14)('d', 6)
# p2 player, money hand: MC player 19528 ('h', 9)('d', 4)
# after move 100000 1951 -1
# reward 1
# j = 107 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 80472 ('c', 6)('c', 2)
# p2 player, money hand: MC player 19528 ('c', 9)('c', 11)
# after move 100000 459 -1
# reward 1
# j = 108 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 80472 ('d', 7)('h', 5)
# p2 player, money hand: MC player 19528 ('s', 7)('d', 3)
# after move 100000 1639 -1
# reward 1
# j = 109 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 80472 ('c', 11)('s', 7)
# p2 player, money hand: MC player 19528 ('s', 12)('s', 14)
# after move 100000 810 -1
# reward 1
# j = 110 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 80472 ('s', 10)('d', 2)
# p2 player, money hand: MC player 19528 ('h', 11)('c', 7)
# after move 100000 836 -1
# reward 1
# j = 111 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 80472 ('c', 7)('d', 14)
# p2 player, money hand: MC player 19528 ('c', 6)('c', 4)
# after move 100000 1125 -1
# reward 1
# j = 112 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 80472 ('d', 6)('h', 9)
# p2 player, money hand: MC player 19528 ('s', 4)('c', 11)
# after move 100000 1473 -1
# reward 1
# j = 113 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 80472 ('c', 12)('h', 12)
# p2 player, money hand: MC player 19528 ('s', 10)('d', 4)
# after move 100000 -1 2000
# reward -1
# j = 114 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 79597 ('h', 9)('h', 2)
# p2 player, money hand: MC player 20403 ('h', 12)('h', 8)
# after move 100000 253 -1
# reward 1
# j = 115 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 79597 ('d', 12)('c', 10)
# p2 player, money hand: MC player 20403 ('s', 8)('h', 6)
# after move 100000 1560 2000
# reward 1
# j = 116 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 81597 ('d', 13)('h', 10)
# p2 player, money hand: MC player 18403 ('d', 10)('h', 6)
# after move 100000 1771 2000
# reward 1
# j = 117 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 83597 ('s', 12)('h', 8)
# p2 player, money hand: MC player 16403 ('d', 11)('c', 8)
# after move 100000 1812 -1
# reward 1
# j = 118 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 83597 ('d', 4)('s', 5)
# p2 player, money hand: MC player 16403 ('s', 4)('s', 9)
# after move 100000 1184 -1
# reward 1
# j = 119 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 83597 ('s', 5)('c', 9)
# p2 player, money hand: MC player 16403 ('s', 9)('c', 2)
# after move 100000 1855 -1
# reward 1
# j = 120 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 83597 ('c', 13)('h', 7)
# p2 player, money hand: MC player 16403 ('h', 13)('h', 5)
# after move 100000 1663 -1
# reward 1
# j = 121 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 83597 ('s', 12)('c', 12)
# p2 player, money hand: MC player 16403 ('d', 10)('d', 2)
# after move 100000 1682 2000
# reward 1
# j = 122 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 85597 ('c', 2)('c', 6)
# p2 player, money hand: MC player 14403 ('s', 3)('d', 9)
# after move 100000 1812 -1
# reward 1
# j = 123 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 85597 ('d', 13)('c', 8)
# p2 player, money hand: MC player 14403 ('h', 5)('d', 7)
# after move 100000 1227 -1
# reward 1
# j = 124 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 85597 ('s', 7)('c', 5)
# p2 player, money hand: MC player 14403 ('s', 6)('h', 7)
# after move 100000 1301 -1
# reward 1
# j = 125 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 85597 ('h', 7)('s', 7)
# p2 player, money hand: MC player 14403 ('c', 14)('h', 14)
# after move 100000 1218 -1
# reward 1
# j = 126 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 85597 ('h', 5)('h', 8)
# p2 player, money hand: MC player 14403 ('s', 14)('h', 6)
# after move 100000 598 -1
# reward 1
# j = 127 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 85597 ('c', 5)('c', 4)
# p2 player, money hand: MC player 14403 ('h', 6)('h', 2)
# after move 100000 252 -1
# reward 1
# j = 128 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 85597 ('s', 11)('d', 6)
# p2 player, money hand: MC player 14403 ('c', 9)('c', 4)
# after move 100000 1130 -1
# reward 1
# j = 129 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 85597 ('h', 2)('d', 10)
# p2 player, money hand: MC player 14403 ('c', 14)('d', 4)
# after move 100000 654 -1
# reward 1
# j = 130 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 85597 ('c', 5)('d', 11)
# p2 player, money hand: MC player 14403 ('h', 6)('d', 4)
# after move 100000 1406 -1
# reward 1
# j = 131 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 85597 ('h', 8)('d', 13)
# p2 player, money hand: MC player 14403 ('d', 6)('d', 11)
# after move 100000 906 -1
# reward 1
# j = 132 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 85597 ('d', 11)('d', 2)
# p2 player, money hand: MC player 14403 ('h', 10)('s', 2)
# after move 100000 957 -1
# reward 1
# j = 133 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 85597 ('h', 7)('c', 3)
# p2 player, money hand: MC player 14403 ('c', 5)('c', 14)
# after move 100000 1162 -1
# reward 1
# j = 134 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 85597 ('c', 5)('s', 6)
# p2 player, money hand: MC player 14403 ('d', 12)('s', 14)
# after move 100000 839 -1
# reward 1
# j = 135 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 85597 ('s', 3)('d', 13)
# p2 player, money hand: MC player 14403 ('h', 13)('c', 3)
# after move 100000 680 -1
# reward 1
# j = 136 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 85597 ('c', 7)('s', 12)
# p2 player, money hand: MC player 14403 ('s', 6)('s', 9)
# after move 100000 1142 -1
# reward 1
# j = 137 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 85597 ('h', 3)('s', 2)
# p2 player, money hand: MC player 14403 ('d', 13)('c', 10)
# after move 100000 567 -1
# reward 1
# j = 138 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 85597 ('d', 4)('c', 9)
# p2 player, money hand: MC player 14403 ('c', 3)('h', 9)
# after move 100000 1190 -1
# reward 1
# j = 139 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 85597 ('d', 13)('d', 6)
# p2 player, money hand: MC player 14403 ('h', 6)('c', 3)
# after move 100000 867 -1
# reward 1
# j = 140 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 85597 ('s', 12)('c', 5)
# p2 player, money hand: MC player 14403 ('h', 9)('d', 4)
# after move 100000 1443 -1
# reward 1
# j = 141 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 85597 ('h', 14)('h', 6)
# p2 player, money hand: MC player 14403 ('d', 4)('c', 9)
# after move 100000 -1 2000
# reward -1
# j = 142 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 84708 ('s', 12)('h', 6)
# p2 player, money hand: MC player 15292 ('s', 14)('c', 3)
# after move 100000 1680 -1
# reward 1
# j = 143 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 84708 ('h', 4)('s', 11)
# p2 player, money hand: MC player 15292 ('d', 8)('h', 2)
# after move 100000 1061 -1
# reward 1
# j = 144 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 84708 ('s', 8)('d', 12)
# p2 player, money hand: MC player 15292 ('s', 2)('s', 10)
# after move 100000 1322 -1
# reward 1
# j = 145 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 84708 ('c', 6)('d', 8)
# p2 player, money hand: MC player 15292 ('d', 5)('h', 5)
# after move 100000 621 -1
# reward 1
# j = 146 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 84708 ('s', 13)('c', 8)
# p2 player, money hand: MC player 15292 ('c', 7)('d', 3)
# after move 100000 1170 -1
# reward 1
# j = 147 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 84708 ('s', 9)('h', 11)
# p2 player, money hand: MC player 15292 ('d', 7)('c', 5)
# after move 100000 801 -1
# reward 1
# j = 148 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 84708 ('s', 2)('c', 10)
# p2 player, money hand: MC player 15292 ('s', 8)('h', 5)
# after move 100000 1904 -1
# reward 1
# j = 149 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 84708 ('c', 5)('c', 12)
# p2 player, money hand: MC player 15292 ('h', 11)('c', 9)
# after move 100000 1016 -1
# reward 1
# j = 150 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 84708 ('s', 11)('h', 14)
# p2 player, money hand: MC player 15292 ('h', 2)('c', 10)
# after move 100000 1884 2000
# reward 1
# j = 151 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 86708 ('d', 12)('h', 9)
# p2 player, money hand: MC player 13292 ('c', 11)('d', 10)
# after move 100000 1604 -1
# reward 1
# j = 152 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 86708 ('d', 12)('c', 11)
# p2 player, money hand: MC player 13292 ('c', 14)('h', 13)
# after move 100000 1014 -1
# reward 1
# j = 153 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 86708 ('s', 2)('h', 12)
# p2 player, money hand: MC player 13292 ('d', 10)('h', 13)
# after move 100000 1827 -1
# reward 1
# j = 154 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 86708 ('c', 9)('d', 3)
# p2 player, money hand: MC player 13292 ('s', 4)('h', 2)
# after move 100000 1359 -1
# reward 1
# j = 155 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 86708 ('s', 5)('d', 7)
# p2 player, money hand: MC player 13292 ('s', 9)('c', 3)
# after move 100000 1647 -1
# reward 1
# j = 156 winner is p1(Random Player)
#
# ...
# reward 1
# j = 162 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 86708 ('s', 3)('c', 14)
# p2 player, money hand: MC player 13292 ('d', 8)('h', 2)
# after move 100000 1842 -1
# reward 1
# j = 163 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 86708 ('s', 5)('h', 8)
# p2 player, money hand: MC player 13292 ('c', 10)('c', 4)
# after move 100000 1650 -1
# reward 1
# j = 164 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 86708 ('s', 14)('d', 7)
# p2 player, money hand: MC player 13292 ('c', 4)('s', 13)
# after move 100000 1266 -1
# reward 1
# j = 165 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 86708 ('h', 8)('h', 7)
# p2 player, money hand: MC player 13292 ('h', 11)('d', 4)
# after move 100000 1201 2000
# reward 1
# j = 166 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 88708 ('c', 5)('d', 3)
# p2 player, money hand: MC player 11292 ('h', 2)('s', 12)
# after move 100000 1241 -1
# reward 1
# j = 167 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 88708 ('s', 4)('s', 12)
# p2 player, money hand: MC player 11292 ('d', 8)('d', 3)
# after move 100000 1437 -1
# reward 1
# j = 168 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 88708 ('d', 10)('d', 9)
# p2 player, money hand: MC player 11292 ('h', 9)('d', 8)
# after move 100000 1099 2000
# reward 1
# j = 169 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 90708 ('s', 9)('h', 4)
# p2 player, money hand: MC player 9292 ('c', 5)('c', 14)
# after move 100000 217 -1
# reward 1
# j = 170 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 90708 ('d', 9)('c', 8)
# p2 player, money hand: MC player 9292 ('d', 7)('s', 3)
# after move 100000 1680 -1
# reward 1
# j = 171 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 90708 ('d', 2)('c', 7)
# p2 player, money hand: MC player 9292 ('c', 9)('c', 5)
# after move 100000 1080 -1
# reward 1
# j = 172 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 90708 ('s', 12)('d', 10)
# p2 player, money hand: MC player 9292 ('h', 7)('s', 5)
# after move 100000 -1 2000
# reward -1
# j = 173 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 89959 ('c', 9)('h', 10)
# p2 player, money hand: MC player 10041 ('c', 2)('c', 8)
# after move 100000 1259 -1
# reward 1
# j = 174 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 89959 ('c', 13)('h', 11)
# p2 player, money hand: MC player 10041 ('c', 11)('s', 8)
# after move 100000 1463 2000
# reward 1
# j = 175 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 91959 ('c', 10)('s', 13)
# p2 player, money hand: MC player 8041 ('s', 8)('d', 6)
# after move 100000 1279 2000
# reward 1
# j = 176 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 93959 ('h', 12)('h', 7)
# p2 player, money hand: MC player 6041 ('d', 10)('c', 10)
# after move 100000 896 -1
# reward 1
# j = 177 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 93959 ('c', 6)('s', 10)
# p2 player, money hand: MC player 6041 ('d', 7)('c', 10)
# after move 100000 1126 -1
# reward 1
# j = 178 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 93959 ('d', 3)('s', 9)
# p2 player, money hand: MC player 6041 ('h', 9)('s', 2)
# after move 100000 315 -1
# reward 1
# j = 179 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 93959 ('h', 10)('d', 9)
# p2 player, money hand: MC player 6041 ('c', 12)('s', 3)
# after move 100000 1201 -1
# reward 1
# j = 180 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 93959 ('c', 7)('s', 2)
# p2 player, money hand: MC player 6041 ('c', 5)('h', 11)
# after move 100000 1752 -1
# reward 1
# j = 181 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 93959 ('c', 11)('d', 3)
# p2 player, money hand: MC player 6041 ('d', 7)('d', 2)
# after move 100000 1459 -1
# reward 1
# j = 182 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 93959 ('s', 13)('c', 12)
# p2 player, money hand: MC player 6041 ('c', 6)('c', 5)
# after move 100000 1179 2000
# reward 1
# j = 183 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 95959 ('h', 6)('s', 10)
# p2 player, money hand: MC player 4041 ('h', 2)('s', 5)
# after move 100000 1262 -1
# reward 1
# j = 184 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 95959 ('s', 4)('c', 11)
# p2 player, money hand: MC player 4041 ('h', 14)('s', 12)
# after move 100000 1910 -1
# reward 1
# j = 185 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 95959 ('s', 7)('s', 10)
# p2 player, money hand: MC player 4041 ('d', 3)('s', 14)
# after move 100000 877 -1
# reward 1
# j = 186 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 95959 ('s', 10)('c', 2)
# p2 player, money hand: MC player 4041 ('c', 14)('d', 2)
# after move 100000 1173 -1
# reward 1
# j = 187 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 95959 ('c', 13)('s', 3)
# p2 player, money hand: MC player 4041 ('c', 6)('d', 10)
# after move 100000 1221 -1
# reward 1
# j = 188 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 95959 ('c', 12)('d', 14)
# p2 player, money hand: MC player 4041 ('d', 4)('h', 14)
# after move 100000 -1 2000
# reward -1
# j = 189 winner is p2(MC player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 95035 ('s', 4)('d', 14)
# p2 player, money hand: MC player 4965 ('d', 3)('s', 8)
# after move 100000 1918 -1
# reward 1
# j = 190 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 95035 ('c', 3)('c', 10)
# p2 player, money hand: MC player 4965 ('c', 8)('h', 12)
# after move 100000 855 -1
# reward 1
# j = 191 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 95035 ('d', 2)('d', 14)
# p2 player, money hand: MC player 4965 ('h', 14)('s', 2)
# after move 100000 1732 2000
# reward 1
# j = 192 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 97035 ('s', 6)('h', 7)
# p2 player, money hand: MC player 2965 ('c', 5)('s', 11)
# after move 100000 1387 -1
# reward 1
# j = 193 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 97035 ('c', 10)('h', 10)
# p2 player, money hand: MC player 2965 ('s', 12)('s', 11)
# after move 100000 705 -1
# reward 1
# j = 194 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 97035 ('d', 4)('c', 4)
# p2 player, money hand: MC player 2965 ('d', 9)('d', 14)
# after move 100000 646 -1
# reward 1
# j = 195 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 97035 ('h', 2)('h', 3)
# p2 player, money hand: MC player 2965 ('c', 3)('s', 10)
# after move 100000 408 -1
# reward 1
# j = 196 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 97035 ('d', 13)('h', 6)
# p2 player, money hand: MC player 2965 ('h', 14)('d', 8)
# after move 100000 387 -1
# reward 1
# j = 197 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 97035 ('h', 12)('s', 11)
# p2 player, money hand: MC player 2965 ('s', 5)('h', 7)
# after move 100000 1851 2000
# reward 1
# j = 198 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 99035 ('d', 2)('h', 7)
# p2 player, money hand: MC player 965 ('c', 10)('h', 12)
# after move 100000 513 -1
# reward 1
# j = 199 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 99035 ('h', 4)('s', 5)
# p2 player, money hand: MC player 965 ('d', 9)('h', 12)
# after move 100000 1731 -1
# reward 1
# j = 200 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 99035 ('d', 7)('d', 6)
# p2 player, money hand: MC player 965 ('s', 2)('c', 5)
# after move 100000 1059 -1
# reward 1
# j = 201 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 99035 ('c', 12)('c', 5)
# p2 player, money hand: MC player 965 ('h', 3)('s', 2)
# after move 100000 976 -1
# reward 1
# j = 202 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 99035 ('c', 2)('h', 14)
# p2 player, money hand: MC player 965 ('s', 4)('c', 5)
# after move 100000 1912 -1
# reward 1
# j = 203 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 99035 ('s', 10)('c', 2)
# p2 player, money hand: MC player 965 ('c', 5)('d', 13)
# after move 100000 1888 -1
# reward 1
# j = 204 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 99035 ('h', 5)('s', 9)
# p2 player, money hand: MC player 965 ('h', 10)('c', 12)
# after move 100000 1995 -1
# reward 1
# j = 205 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 99035 ('s', 8)('c', 13)
# p2 player, money hand: MC player 965 ('c', 11)('s', 5)
# after move 100000 1537 -1
# reward 1
# j = 206 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 99035 ('c', 13)('s', 8)
# p2 player, money hand: MC player 965 ('h', 9)('h', 6)
# after move 100000 1226 -1
# reward 1
# j = 207 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 99035 ('c', 8)('d', 4)
# p2 player, money hand: MC player 965 ('c', 7)('s', 8)
# after move 100000 566 -1
# reward 1
# j = 208 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 99035 ('d', 8)('h', 7)
# p2 player, money hand: MC player 965 ('c', 12)('h', 13)
# after move 100000 685 -1
# reward 1
# j = 209 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 99035 ('s', 11)('d', 5)
# p2 player, money hand: MC player 965 ('d', 3)('h', 9)
# after move 100000 636 -1
# reward 1
# j = 210 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 99035 ('h', 2)('h', 11)
# p2 player, money hand: MC player 965 ('s', 8)('h', 8)
# after move 100000 1801 -1
# reward 1
# j = 211 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 99035 ('h', 13)('d', 6)
# p2 player, money hand: MC player 965 ('c', 8)('s', 5)
# after move 100000 509 -1
# reward 1
# j = 212 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 99035 ('d', 8)('c', 8)
# p2 player, money hand: MC player 965 ('d', 6)('h', 7)
# after move 100000 1729 2000
# reward 1
# j = 213 winner is p1(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : Random Player 101035 ('d', 3)('s', 2)
# p2 player, money hand: MC player -1035 ('c', 9)('s', 10)
# Player Balance Under 0, End this Game.
#
#
# table= 0 p1(Random Player) = 204 p2(MC player) = 10 draw = 0
# p1.bal= 101035 p2.bal=-1035 sum = 100000
