# %%
# -*- conding: utf-8 -*-
import numpy   as np
import random
import copy
import time
import csv

# %%
class Environment:
    #게임판 구성, 안되는 상태, 완료된 상태, 보상 정의
    #게임판 핸드만 두장 줌, 베팅 한 번씩 물어봄. 리레이즈 1회만 가능

    # 덱을 만듬. 턴, 판돈, 플레이어가 베팅한 횟수 설정

    def __init__(self):
        self.done = False #True면 게임 종료
        #self.winner = 0
        self.reward = 0
        self.turn = 0
        self.table = 0
        self.player_calls =0
        self.lowlimit = 200
        self.maxlimit = 2000
        self.bet1 = -2
        self.bet2 = -2
        self.last_bet = -2
        deck = [(suit, i) for suit in ["s", "h", "d", "c"] for i in range(2, 15)]  ##카드 덱 만들기, 튜플로 구성된 리스트
        random.shuffle(deck)
        self.deck = deck

    # 보상을 정의  handcheck, ai_action은 agent가 준다.
    def pf_reward(self, handcheck, ai_action):
        #print('hc, a', handcheck, ai_action)
        if (handcheck == 1) and (ai_action > 0):
            # if ai_action >= 0:  # 콜, 레이즈, 체크
            rwd = -1
        elif (handcheck == 1) and (ai_action < 0):  # 폴드한 경우
            rwd = +1

        elif (handcheck != 1) and (ai_action > 0):
            # if ai_action >= 0:  # 콜, 레이즈, 체크
            rwd = +1
        else:  # 폴드한 경우
            rwd = -1

        return rwd

    def move(self, p1,p2):
        #각플레이어가 선택한 행동 table에 반영하고 게임 상태 판단
        #p1 = 1, p2 = -1
        #각 플레이어는 행동을 선택하는 메서드를 가짐 selct_action
        
        self.table += 400 # Blind 
        p1.bal -= 200
        p2.bal -= 200

        self.bet1 = p1.select_action(env) # 행동 선택 1
        self.last_bet = self.bet1
        if self.bet1 == -1: #폴드한 경우, 판돈에 돈을 넣지 않음
          pass
        else:
          self.table += self.bet1
        self.player_calls += 1 # p1 행동 카운트#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
       
        #else:
        self.bet2 = p2.select_action(env)#, player) # p2 행동 선택
        self.last_bet = self.bet2
        if self.bet2 == -1:
            pass
        else:
          self.table += self.bet2 # p2의 금액 추가 #@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
        self.player_calls += 1 # p2 의 행동 카운트 #@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@

        if (self.bet1>=0) and (self.bet2 > self.bet1): #리레이즈 
          #print('p1 action, p2 action', self.bet1, self.bet2)
          #self.player_calls += 1 # 확인
          self.bet1 = p1.select_action(env) # 한번 더 행동을 받음 # 행동선택 3 
          self.player_calls += 1 # 다시 p1 의 행동 카운트 #@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
          self.last_bet = self.bet1
          if self.bet1 == -1:
            pass
          else:
            self.table += self.bet1

        else:
          self.player_calls += 1 # 행동 3번으로 맞추기 용도#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@

        #print('table: {}, last_bet: {}'.format( self.table, self.last_bet))
        self.last_bet = -2 #원상복구
        #게임 상태가 종료인지 판단, 누가 이겼는지 체크
        #print('p calls', env.player_calls)
        self.end_check(p1,p2)
        self.player_calls =0
        return self.reward, self.done

    #현재 베팅 가능한 상태 수집.
    def get_action(self):
        observation = [-1,0]
        #table이 0이 아니다. -> 누군가 베팅을 했다면 lowlimit 이 그 두배로 바뀜

        if self.last_bet > 0:
          if self.last_bet*2 > 2000:
            self.lowlimit = 2000
          else:
            self.lowlimit =  self.last_bet*2
        #print('self.last_bet:{}, self.lowlimit:{}'.format(self.last_bet, self.lowlimit))
        for i in range(self.lowlimit, self.maxlimit+1,10): #이 부분 변경하면 경우의 수를 줄일 수 있음.
            observation.append(i)
        #print("in get action observation[] : ", observation)
        return observation

    #게임 종료 판단
    def end_check(self, p1,p2):
        if (self.player_calls >= 3): #

            #판돈에 플레이어의 베팅을 반영 및 표시
            if (self.bet1 == -1): #P1 폴드 
              p2.bal += self.table
              self.table = 0
              self.reward = -1 # 승자는 p2
              self.done = True
              
            elif (self.bet2 == -1): # P2 폴드
              p1.bal += self.table
              self.table = 0
              self.reward = 1 #승자는 p1
              self.done = True
              
            else: # 카드 점수 계산 
              # 1. p1 승리
              if self.hand_check(p1.hand1, p1.hand2) > self.hand_check(p2.hand1, p2.hand2):
                  self.reward = 1
                  p1.bal += self.table  # 테이블의 돈을 가져감
                  self.table = 0
                  self.done = True
              # 2. p2 승리
              elif self.hand_check(p1.hand1, p1.hand2) < self.hand_check(p2.hand1, p2.hand2):
                  self.reward = -1
                  p2.bal += self.table  # 테이블의 돈을 가져감
                  self.table = 0
                  self.done = True
              # 3. p1 p2카드가 같다. -> 무승부 판돈 분할
              else:
                  self.reward = 0
                  p1.bal += self.table/2
                  p2.bal += self.table/2
                  self.table = 0
                  self.done = True # 돈은 그대로 남아있음.
        else:
            pass
        return

    def print_poker(self, player):
        print('\n------------------Turn : %d-------------------\n'%self.turn)
        print('Table Money: %d'%self.table)
        print('Now Bet: %s'%player.name)

    # 핸드 순위 확인
    def hand_check(self, hand1, hand2):  # 핸드체크, 프레플랍 단계 먼저 자신에게 주어진 카드 정보를 분석한다.
        premium = [('p', 14, 14), ('p', 13, 13), ('p', 12, 12), ('s', 14, 13), ('p', 11, 11), ('s', 14, 12),
                   ('s', 13, 12), ('s', 14, 11), ('s', 13, 11), ('p', 10, 10), ('o', 14, 13), ('s', 14, 10),
                   ('s', 12, 11), ('s', 13, 10), ('s', 12, 10), ('s', 11, 10), ('p', 9, 9)]
        special = [('o', 14, 12), ('s', 14, 9), ('o', 13, 12), ('p', 8, 8), ('s', 13, 9), ('s', 10, 9),
                   ('s', 14, 8),
                   ('s', 12, 9), ('s', 11, 9), ('o', 14, 11), ('s', 14, 5), ('p', 7, 7), ('s', 14, 7),
                   ('o', 13, 11),
                   ('s', 14, 4), ('s', 14, 3), ('s', 14, 6)]
        good = [('o', 12, 11), ('p', 6, 6), ('s', 13, 8), ('s', 10, 8), ('s', 14, 2), ('s', 9, 8), ('s', 11, 8),
                ('o', 14, 10), ('s', 12, 8), ('s', 13, 7), ('o', 13, 10), ('p', 5, 5), ('o', 11, 10), ('s', 8, 7),
                ('o', 12, 10), ('p', 4, 4), ('p', 3, 3), ('p', 2, 2)]
        # 숫자 비교 후 pair인지 확인(pair이면 p, 아니면 문자 확인으로 넘어감), 문자 확인해서 일치하는지 확인(불일치 하면 o, 일치하면 s ),  숫자 조합해서 하나의 튜플로 제작
        if hand1[1] == hand2[1]:
            tup1 = 'p'
        else:
            if hand1[0] == hand2[0]:
                tup1 = 's'
            else:
                tup1 = 'o'

        if hand1[1] > hand2[1]:  # 숫자 큰 게 앞으로 오게 함
            tup2, tup3 = hand1[1], hand2[1]
        else:
            tup2, tup3 = hand2[1], hand1[1]

        tup = (tup1, tup2, tup3)  # 튜플 생성
        #print('tup', tup)
        if premium.count(tup) == 1:
            return 4  # ('premium')
        elif special.count(tup) == 1:
            return 3  # ('special')
        elif good.count(tup) == 1:  # 판단
            return 2  # ('good')
        else:
            return 1  # ('fold')

# %%
class Human_player:
    
    
    def __init__(self):
        self.name = 'Human Player'
        self.bal = 50000
        self.hand1 = 0
        self.hand2 = 0
    
    
    def select_action(self, env):#,player):
        while True:
            available_action = env.get_action()
            if (env.bet1 >= 0) and (env.bet2>= 2*env.bet1): #리레이즈의 상황이라면  0614 changed from here @@@@@@@@@@@@@#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
              available_action = [-1, 0]#env.bet2] #폴드하거나 p2 bet 콜만 함 #@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
              #env.maxlimit = env.bet2
              print('possible action: ', available_action)#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
              print('{} Hands: {} {}'.format(self.name, self.hand1, self.hand2))#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
              print('player_calls',env.player_calls)#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
              action = int(input('fold: -1 , call: 0\n'))#{}\n'.format(env.bet2)))#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@

            else:#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
             print('possible action: ', available_action)#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
             print('{} Hands: {} {}'.format(self.name, self.hand1, self.hand2))#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
             action = int(input('fold: -1, call: 0, {} <= raise <= {}\n'.format(env.lowlimit, env.maxlimit)))#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
                # until here @@@@@@@@@@@@@@@@@@@@@@@@

            if action in available_action:
              if action == 0: # 콜/체크라면 상대가 제시한 만큼 내게 됨. 추후 라운드 추가시 변경
                if (env.player_calls == 0) and (env.last_bet==-2):
                  action = 0
                  
                elif env.player_calls == 1:
                  action = env.last_bet# p1이 제시한 금액에 p2가 콜하는 경우 
                else:
                  action = env.last_bet - env.bet1 #p2가 제시한 금액에 p1이 콜하는 경우 #@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@

              if action == -1:
                pass
              else:
                self.bal -= action
              break # 0614 break @@@@@@@@@@@@@@@@@@@@@@@@@@#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
            else:
                print("Wrong Action. Try Again")
        print('Human action: ', action)
        return action # 0614 action @@@@@@@@@@@@@@@@@@@@@@@@#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@

# %%
class Random_player:
    
    def __init__(self):
        self.name = 'Random Player'
        self.bal = 50000
        self.hand1 = 0
        self.hand2 = 0

    def select_action(self, env):
        
        available_action = env.get_action()
        #print(env.bet1)
        if (env.bet1 >= 0) and (env.bet2>= 2*env.bet1): #리레이즈의 상황이라면 #@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
          available_action = [-1, 0] #폴드, 콜만 함#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@

        action = random.choice(available_action) # 임의로 행동 선택

        #print('player_calls, available_action', env.player_calls, available_action)
        if action == 0: # 콜/체크라면 상대가 제시한 만큼 내게 됨. 추후 라운드 추가시 변경
          if (env.player_calls == 0) and (env.last_bet==-2):
            action = 0
          elif env.player_calls == 1:
            action = env.last_bet# p1이 제시한 금액에 p2가 콜하는 경우 
          else:
            action = env.last_bet - env.bet1 #p2가 제시한 금액에 p1이 콜하는 경우 #@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@

        if action == -1:
          pass
        else:
          self.bal -= action
        #print("rand P action : ", action)
        return action

# %%
class Monte_Carlo_player:
  def __init__(self):
    self.name = "MC Player"
    self.num_playout = 80 # 최대 약 1300  예상, 덱에서 2장 뽑는 경우의 수 고려.
    self.bal = 50000
    self.hand1 = 0
    self.hand2 = 0
    self.select_time1 = 0
    self.select_time2 = 0 
    self.bluff = ['y','y','y','y','y','n','n','n','n','n'] # 블러핑 확률 계산용
   #self.luck = 0
   # self.win = 0
   # self.lose = 0
   # self.draw = 0
    #self.count = 0

  def bluffing(self):
 #@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@0617@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
    #블러핑 시도 하기 1. 잔고 확인. 잔고에 따라 확률이 바뀜. 잔고 앞자리를 따라 y, n 개수가 변함. y 개수가 많으면 확률 증가, 리스트에서 하나 뽑아서 y면 블러핑 실행, n이면 일반
    # 2. 잔고가 3만 이상일 때,handcheck 결과가 3인 경우 높은 special에 해당하는 금액이 아닌 콜을 함. 
    # 2. 잔고가 5만 이상일 때, handcheck 결과가 1인 경우 premium에 해당하는 카드를 몬테카를로에 부여함. 

    #bluff = ['y','y','y','y','y','n','n','n','n','n'] # 블러핑 확률 계산용
    print('bluff: ', self.bluff)
    now_bal = str(self.bal)
    y_count = int(now_bal[0])
    print("y_count , bluff.count('y')", y_count, self.bluff.count('y'))
    while y_count != self.bluff.count('y'):
      print('working y')
      if y_count < self.bluff.count('y'): # 돈 앞자리가 y 갯수보다 작면 y를 없앰
        self.bluff.pop(0)
        print(self.bluff)
      else:
        self.bluff.insert(0,'y')
        print(self.bluff)
    while len(self.bluff) <= 10: # n으로 채워서 길이를 맞춤
      print('working len')
      self.bluff.append('n')
    if len(self.bluff)> 10:
      self.bluff.pop()

    is_bluff = random.choice(self.bluff) # 블러핑 여부 저장
    card_rate = env.hand_check(self.hand1, self.hand2)

    if is_bluff == 'y':
      if (self.bal>30000) and card_rate == 3:
        if self.
        self.hand1 = ('s', 5)
        self.hand2 = ('s', 6)
      elif (self.bal>50000) and card_rate == 1:
        self.hand1 = ('s', 9)
        self.hand2 = ('d', 9)
      else:
        pass
    else:
      pass



  def select_action(self, env):
    select_time = time.time()
    #가능한 행동 조사
    #self.count += 1
    #print('self.count: ',self.count)

    available_action = env.get_action()
    if (env.bet1>=0) and (env.bet2>= 2*env.bet1): #리레이즈의 상황이라면 #@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
      available_action = [-1, 0] #폴드하거나 콜만 함#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
    # 모든 카드의 경우의 수와 점수 쌍을 모을 딕셔너리 {'카드1,카드2,' : [0, 0, ... ,0]} 의 형태 
    Q_val_dict = {} 
    #print('MC available action', available_action)
    total_action = [-1, 0] # 게임에서 가능한 모든 행동 
    for i in range(200,2001):
      total_action.append(i)
    
    T = [] # 게임상 가능한 행동 개수만큼 0으로 채운 점수판 생성
    for i in range(1803):
      T.append(0)


    temp_p1 = Random_player()
    temp_p1.name = p1.name
    temp_p1.bal = p1.bal

    temp_p2 = Random_player()
    temp_p2.name = p2.name
    temp_p2.bal = p2.bal

    if temp_p1.name == 'MC Player': #실제 카드 부여 
      
      temp_p1.hand1 = p1.hand1
      temp_p1.hand2 = p1.hand2
      
      temp_p1_deck = (temp_p1.hand1, temp_p1.hand2)
    
    if temp_p2.name == 'MC Player':
      temp_p2.hand1 = p2.hand1
      temp_p2.hand2 = p2.hand2
      
      temp_p2_deck = (temp_p2.hand1, temp_p2.hand2)
    
    self.bluffing()
    print('MC hands: ', self.hand1, self.hand2)

    #print(temp_p1_deck, temp_p2_deck)    
    for i in range(len(available_action)):

      #플레이아웃을 1000번 반복
      for j in range(self.num_playout):

        #지금 상태를 복사해서 블레이 아웃에 사용
        temp_env = copy.deepcopy(env)
        
        deck = [(suit, i) for suit in ["s", "h", "d", "c"] for i in range(2, 15)]  ##카드 덱 만들기, 튜플로 구성된 리스트
        random.shuffle(deck) # 플레이아웃용 deck 만들기 
        
        if temp_p1.name == 'MC Player': 
          #deck.remove(temp_p1.hand1) #@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
          #deck.remove(temp_p1.hand2)#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
            
          temp_env.deck = deck
          temp_p2.hand1, temp_p2.hand2 = deck.pop(), deck.pop() # 상대방에게 임의로 카드 2장 부여 

        if temp_p2.name == 'MC Player':
          #deck.remove(temp_p2.hand1)#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
          #deck.remove(temp_p2.hand2)#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
          
          temp_env.deck = deck
          temp_p1.hand1, temp_p1.hand2 = deck.pop(), deck.pop()

        #print(temp_p1.hand1,temp_p1.hand2, temp_p2.hand1, temp_p2.hand2)  # 카드 확인
        if temp_p1.name == 'MC Player':
        #이전에 존재하지 않은 p1의 덱이라면 모든 행동 길이만큼의 점수판 리스트를 val 값으로 가짐
          if temp_p1_deck not in Q_val_dict.keys():
            Q_val_dict[temp_p1_deck] = T 
        if temp_p2.name == 'MC Player':
          if temp_p2_deck not in Q_val_dict.keys():
            Q_val_dict[temp_p2_deck] = T
          
         # 가상 게임 실행, 현재 가능한 행동 안에서 루프를 수행함. 
        self.playout(temp_env, available_action[i], temp_p1, temp_p2) 
        #input()
        #플레이 아웃의 결과는 승리 플레이어의 값으로 반환
        #p1이 이기면 reward = 1, p2가 이기면 reward = -1IT
        #if temp_env.reward ==1:
        #print('temp 보상',temp_env.reward)
        if temp_p1.name == 'MC Player':
          result_point = Q_val_dict[temp_p1_deck]
        if temp_p2.name == 'MC Player':
          result_point = Q_val_dict[temp_p2_deck]

        if temp_p1.name == 'MC Player': #p1이 MC일 때 
          if temp_env.reward == 1: #p1이 승리한 경우
        # p1이 베팅한 금액이 게임상 가능한 액션 중에 몇 번째인지 점수판으로 가져와서 해당 인덱스에 +1
           # print(result_point[total_action.index(temp_env.bet1)])
            result_point[total_action.index(temp_env.bet1)] += 1 
           # self.win += 1
        if temp_p2.name == 'MC Player':
          if temp_env.reward == -1:
            result_point[total_action.index(temp_env.bet2)] += 1 
          #  self.win += 1 
        #luck = 1- (result_point.count(0)/self.num_playout)
        #luck = self.win/self.num_playout
        #self.luck += luck 
       # print('lucky? ', luck, self.luck)
    #print('result_point: ',  result_point)
     # 점수판에서 최대인 지점의 인덱스를 가져옴
    action_index = result_point.index(max(result_point))
    #print('action_index: ', action_index)
    # 게임상 가능한 모든 행동 중에서 가져온 인덱스에 있는 베팅값 제시 
    action = total_action[action_index] 
    if env.hand_check(self.hand1,self.hand2) <2:
      action=-1
    #print('MC aciton: ', action)
   # print('opponent bet: ', env.bet2 )
    #print('env.player_calls', env.player_calls)
    '''if env.player_calls == 3:
      if action < env.last_bet:
        action = -1'''
    #print('len(avilable_action', len(available_action))
    if action == -1: #@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
      #print('그냥 콜하라고!!!!')
      if (len(available_action) <= 3) and (env.hand_check(self.hand1, self.hand2) >=2): # 승률 높이기 용 @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
        action = 0#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
  
    if action == 0: # 콜/체크라면 상대가 제시한 만큼 내게 됨. 추후 라운드 추가시 변경
      if (env.player_calls == 0) and (env.last_bet==-2):
        action = 0
      elif env.player_calls == 1:
        action = env.last_bet# p1이 제시한 금액에 p2가 콜하는 경우 
      else:
        action = env.last_bet - env.bet1 #p2가 제시한 금액에 p1이 콜하는 경우 #@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@


    if action == -1:
        pass
    else:
      self.bal -= action
    #수행시간 기록 
    if not self.select_time1:
        self.select_time1 = (time.time() - select_time)
    else:
        self.select_time2 = (time.time() - select_time)
    #print('MC select_time(s): %.3f'%(time.time() - select_time))
    #luck = 0 
    return action

  #플레이아웃 재귀 함수
  # 게임이 종료 상태(승/패/비김)가 될 때까지 행동을 임의로 선택하는 것을 반복
  def playout(self, temp_env, action,temp_p1, temp_p2):#, player):
    #판돈에 플레이어의 베팅을 반영 및 표시
  
    if temp_p1.name == 'MC Player':
      temp_env.bet1 = action
      temp_env.table += temp_env.bet1
    if temp_p2.name == 'MC Player':
      temp_env.bet2 = action
      temp_env.table += temp_env.bet2
    #print('temp_env.bet1,temp_env.bet2,temp_env.table',temp_env.bet1,temp_env.bet2,temp_env.table)
    temp_env.player_calls += 1
   # print('temp_env.endcheck', temp_env.player_calls)
    
    #가능한 행동 조사 
    #a무작위로 행동을 선택
    if temp_p1.name == 'MC Player':
      temp_env.bet2 = temp_p2.select_action(temp_env)
      if temp_env.player_calls >2:
        temp_env.bet2 = env.bet2
     # print('temp_env.bet2',temp_env.bet2)
      temp_env.table += temp_env.bet2
    if temp_p2.name == 'MC Player':
      temp_env.bet1 = temp_p1.select_action(temp_env)
      temp_env.table += temp_env.bet2
      if temp_env.player_calls >2:
        temmp_env.bet1 = env.bet1
    temp_env.player_calls += 1
   # print('temp_env.endcheck', temp_env.player_calls)

    #게임 종료 체크 
    if temp_env.player_calls >= 2:#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
     # print('temp_env.endcheck', temp_env.player_calls)
      temp_env.player_calls = 3#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
      temp_env.end_check(temp_p1, temp_p2)
      temp_env.player_calls =0

# %%
#베팅 금액별 프린트 
class Printer:
  
  def round_info(self, p1, p2, env): # p1.name, p2.name, p1.bal, p2.bal, ):
    if p1.name == 'MC Player':
      p = 'P1'
      balance = p1.bal
      select_time1 = p1.select_time1
      select_time2 = p1.select_time2

      
    if p2.name == 'MC Player':
      p = 'P2'
      balance = p2.bal
      select_time1 = p2.select_time1
      select_time2 = p2.select_time2
      
    if env.reward == 1:
      winner = 'P1'
    else:
      winner = 'P2'
    
    r = (p, balance, select_time1, select_time2, winner)

    f = open('round_info_100.csv', 'a', encoding='utf-8', newline='')
    wr = csv.writer(f)
    wr.writerow(r)
    f.close()

  def after_round(self, game_time, p1,p2, p1_score, p2_score, draw_score, j):
    player = 'player'#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
    win_rate = 0#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
    balance = 0#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
    if p1.name == 'MC Player':
      player = 'P1'
      balance = p1.bal
      win_rate = p1_score/(p1_score +p2_score + draw_score)

    if p2.name == 'MC Player':
      player = 'P2'
      balance = p2.bal
      win_rate = p2_score/(p1_score +p2_score + draw_score)

    complete_round = 1+j	
    
    r = (complete_round, game_time, player, win_rate, balance)
    
    f = open('after_round_100.csv', 'a', encoding='utf-8', newline='')
    wr = csv.writer(f)
    wr.writerow(r)
    f.close()

# %%
p1 = Monte_Carlo_player()
#p1 = Random_player()
#p1 = Human_player()
p2 = Random_player()
#p2 = Monte_Carlo_player()
#p2 = Human_player()
prt = Printer()
# 지정된 게임 수를 자동으로 두게 할 것인지 한 게임씩 두게 할 것인지 결정
# auto = True : 지정된 판 수 (games)를 자동으로 진행
# auto = Flase: 한 게임씩 진행
auto = True

#auto 모드의 게임 수
games = 100


#각 플레이어의 승리 횟수를 저장
p1_score = 0
p2_score = 0
draw_score = 0

# %%
start = time.time()
if auto:

    #자동모드 실행
    for j in range(games):
        np.random.seed(j)
        env = Environment()
        p1.hand1, p1.hand2 = env.deck.pop(), env.deck.pop()
        p2.hand1, p2.hand2 = env.deck.pop(), env.deck.pop()
        print('\n------------------------------------------------------------------------------------------------------------------')
        print("p1 player, money, hand : {} {} {}{}".format(p1.name, p1.bal, p1.hand1, p1.hand2))
        print("p2 player, money hand: {} {} {}{}".format(p2.name, p2.bal, p2.hand1, p2.hand2))
        
        if (p1.bal < 0) or (p2.bal <0):
          print('Player Balance Under 0, End this Game.\n')
          break
        for i in range(10000):
            sum = p1.bal+p2.bal
           
            reward, done = env.move(p1,p2) #,(-1)**i)
            print('각자 베팅',env.bet1, env.bet2)
            print('reward, done', reward, done)
            print("{} 잔고: {}, {} 잔고: {} 잔고합계 {}".format(p1.name, p1.bal, p2.name, p2.bal, p1.bal+p2.bal))
            print('after move',sum, env.bet1, env.bet2)
            if sum != 100000:
              print('after move',sum, env.bet1, env.bet2)
              input()
            
            #prt.round_info(p1,p2,env) # 라운드 수행결과 프린트
            # 게임 종료 체크
            if done == True:
                if reward == 1:
                    print("j = {} winner is p1({})".format(j, p1.name))
                    p1_score += 1
                elif reward == -1:
                    print("j = {} winner is p2({})".format(j, p2.name))
                    p2_score += 1
                else:
                    print("j = {} winner is draw".format(j))
                    draw_score += 1
                break
    print("Good Game!")
    print("\n현재 라운드: {}\n{} 승리 횟수: {} {} 승리 횟수: {} 비긴 횟수: {}".format(j+1, p1.name, p1_score, p2.name, p2_score, draw_score))#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
    print("{} 잔고: {}, {} 잔고: {} 잔고합계 {}".format(p1.name, p1.bal, p2.name, p2.bal, p1.bal+p2.bal))
    game_time = time.time() - start
    print("수행 시간: {}".format(game_time))
    prt.after_round(game_time, p1, p2, p1_score, p2_score, draw_score, j)
    
else:
    #한 게임씩 진행하는 수동 모드
    while True:
        #env = Environment()
        env = Environment()
        p1.hand1, p1.hand2 = env.deck.pop(), env.deck.pop()
        p2.hand1, p2.hand2 = env.deck.pop(), env.deck.pop()
        print('------------------------------------------------------------------------------------------------------------------')
        print("p1 player, money, hand : {} {} {}{}".format(p1.name, p1.bal, p1.hand1, p1.hand2))
        print("p2 player, money hand: {} {} {}{}".format(p1.name, p2.bal, p2.hand1, p2.hand2))
        #print('------------------------------------------------------------------------------------------------------------------')
        #env.print = True

        for i in range(10000):
            # p1, p2 번갈아가면서 게임을 진행
            # p1(1) -> p2(-1)
            reward, done = env.move(p1, p2, (-1)**i)
            print('reward', reward)
            # 게임 종료 체크
            if done == True:
                if reward == 1:
                    print("Winner is p1({})".format(p1.name))
                    p1_score += 1
                elif reward == -1:
                    print("Winner is p2({})".format(p2.name))
                    p2_score += 1
                else:
                    print("No Winner")
                    draw_score += 1
                break

        print("final result")
        env.print_poker(p1)

        print("final result")
        env.print_poker(p2)

        # one more?
        answer = input("more Game? (y/n)")
        print("table= {} p1({}) = {} p2({}) = {} draw = {}".format(env.table, p1.name, p1_score, p2.name, p2_score, draw_score))
        if answer == 'y':
            pass
        else:
            print("Good Game!")
            print("\n현재 라운드: {}\n{} 승리 횟수: {} {} 승리 횟수: {} 비긴 횟수: {}".format(j+1, p1.name, p1_score, p2.name, p2_score, draw_score))#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
            print("{} 잔고: {}, {} 잔고: {} 잔고합계 {}".format(p1.name, p1.bal, p2.name, p2.bal, p1.bal+p2.bal))
            print("수행 시간: {}".format(time.time() - start))
# Out:
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 50000 ('s', 11)('h', 4)
# p2 player, money hand: Random Player 50000 ('s', 8)('c', 3)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 4 5
# working y
# ['y', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n']
# working len
# working len
# MC hands:  ('s', 11) ('h', 4)
# 각자 베팅 -1 1370
# reward, done -1 True
# MC Player 잔고: 49800, Random Player 잔고: 50200 잔고합계 100000
# after move 100000 -1 1370
# j = 0 winner is p2(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 49800 ('s', 12)('d', 12)
# p2 player, money hand: Random Player 50200 ('h', 10)('c', 11)
# bluff:  ['y', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 4 4
# working len
# MC hands:  ('s', 12) ('d', 12)
# bluff:  ['y', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 4 4
# working len
# MC hands:  ('s', 12) ('d', 12)
# 각자 베팅 300 510
# reward, done 1 True
# MC Player 잔고: 50510, Random Player 잔고: 49490 잔고합계 100000
# after move 100000 300 510
# j = 1 winner is p1(MC Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 50510 ('d', 9)('h', 6)
# p2 player, money hand: Random Player 49490 ('d', 14)('h', 8)
# bluff:  ['y', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 5 4
# working y
# ['y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n', 'n']
# MC hands:  ('s', 9) ('d', 9)
# 각자 베팅 1030 -1
# reward, done 1 True
# MC Player 잔고: 50710, Random Player 잔고: 49290 잔고합계 100000
# after move 100000 1030 -1
# j = 2 winner is p1(MC Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 50710 ('h', 8)('s', 7)
# p2 player, money hand: Random Player 49290 ('s', 3)('c', 10)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 5 5
# working len
# MC hands:  ('s', 9) ('d', 9)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 5 5
# working len
# MC hands:  ('s', 9) ('d', 9)
# 각자 베팅 790 1240
# reward, done 1 True
# MC Player 잔고: 52150, Random Player 잔고: 47850 잔고합계 100000
# after move 100000 790 1240
# j = 3 winner is p1(MC Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 52150 ('s', 13)('s', 2)
# p2 player, money hand: Random Player 47850 ('h', 14)('s', 12)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 5 5
# working len
# MC hands:  ('s', 13) ('s', 2)
# 각자 베팅 -1 1720
# reward, done -1 True
# MC Player 잔고: 51950, Random Player 잔고: 48050 잔고합계 100000
# after move 100000 -1 1720
# j = 4 winner is p2(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 51950 ('d', 10)('h', 10)
# p2 player, money hand: Random Player 48050 ('s', 7)('c', 4)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 5 5
# working len
# MC hands:  ('d', 10) ('h', 10)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 5 5
# working len
# MC hands:  ('d', 10) ('h', 10)
# 각자 베팅 600 2000
# reward, done 1 True
# MC Player 잔고: 54150, Random Player 잔고: 45850 잔고합계 100000
# after move 100000 600 2000
# j = 5 winner is p1(MC Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 54150 ('d', 9)('s', 8)
# p2 player, money hand: Random Player 45850 ('h', 10)('d', 14)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 5 5
# working len
# MC hands:  ('s', 9) ('d', 9)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 5 5
# working len
# MC hands:  ('s', 9) ('d', 9)
# 각자 베팅 1460 1660
# reward, done 1 True
# MC Player 잔고: 56010, Random Player 잔고: 43990 잔고합계 100000
# after move 100000 1460 1660
# j = 6 winner is p1(MC Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 56010 ('h', 5)('s', 14)
# p2 player, money hand: Random Player 43990 ('h', 14)('c', 2)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 5 5
# working len
# MC hands:  ('h', 5) ('s', 14)
# 각자 베팅 -1 1000
# reward, done -1 True
# MC Player 잔고: 55810, Random Player 잔고: 44190 잔고합계 100000
# after move 100000 -1 1000
# j = 7 winner is p2(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 55810 ('s', 3)('h', 4)
# p2 player, money hand: Random Player 44190 ('s', 9)('s', 2)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 5 5
# working len
# MC hands:  ('s', 3) ('h', 4)
# 각자 베팅 -1 1390
# reward, done -1 True
# MC Player 잔고: 55610, Random Player 잔고: 44390 잔고합계 100000
# after move 100000 -1 1390
# j = 8 winner is p2(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 55610 ('s', 6)('h', 7)
# p2 player, money hand: Random Player 44390 ('c', 4)('d', 12)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 5 5
# working len
# MC hands:  ('s', 6) ('h', 7)
# 각자 베팅 -1 1230
# reward, done -1 True
# MC Player 잔고: 55410, Random Player 잔고: 44590 잔고합계 100000
# after move 100000 -1 1230
# j = 9 winner is p2(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 55410 ('d', 10)('d', 8)
# p2 player, money hand: Random Player 44590 ('c', 7)('s', 2)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 5 5
# working len
# MC hands:  ('d', 10) ('d', 8)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 5 5
# working len
# MC hands:  ('d', 10) ('d', 8)
# 각자 베팅 2000 2000
# reward, done 1 True
# MC Player 잔고: 57610, Random Player 잔고: 42390 잔고합계 100000
# after move 100000 2000 2000
# j = 10 winner is p1(MC Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 57610 ('h', 9)('d', 7)
# p2 player, money hand: Random Player 42390 ('h', 11)('c', 10)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 5 5
# working len
# MC hands:  ('s', 9) ('d', 9)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 5 5
# working len
# MC hands:  ('s', 9) ('d', 9)
# 각자 베팅 790 2000
# reward, done 1 True
# MC Player 잔고: 59810, Random Player 잔고: 40190 잔고합계 100000
# after move 100000 790 2000
# j = 11 winner is p1(MC Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 59810 ('h', 14)('d', 5)
# p2 player, money hand: Random Player 40190 ('d', 2)('d', 7)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 5 5
# working len
# MC hands:  ('s', 9) ('d', 9)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 5 5
# working len
# MC hands:  ('s', 9) ('d', 9)
# 각자 베팅 1630 1880
# reward, done 1 True
# MC Player 잔고: 61890, Random Player 잔고: 38110 잔고합계 100000
# after move 100000 1630 1880
# j = 12 winner is p1(MC Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 61890 ('d', 6)('s', 3)
# p2 player, money hand: Random Player 38110 ('s', 9)('s', 10)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 6 5
# working y
# ['y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n']
# MC hands:  ('d', 6) ('s', 3)
# 각자 베팅 -1 500
# reward, done -1 True
# MC Player 잔고: 61690, Random Player 잔고: 38310 잔고합계 100000
# after move 100000 -1 500
# j = 13 winner is p2(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 61690 ('d', 8)('c', 9)
# p2 player, money hand: Random Player 38310 ('h', 7)('s', 7)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 6 6
# working len
# MC hands:  ('d', 8) ('c', 9)
# 각자 베팅 -1 420
# reward, done -1 True
# MC Player 잔고: 61490, Random Player 잔고: 38510 잔고합계 100000
# after move 100000 -1 420
# j = 14 winner is p2(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 61490 ('d', 2)('c', 3)
# p2 player, money hand: Random Player 38510 ('c', 10)('c', 12)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 6 6
# working len
# MC hands:  ('s', 9) ('d', 9)
# 각자 베팅 1030 1030
# reward, done 0 True
# MC Player 잔고: 61490.0, Random Player 잔고: 38510.0 잔고합계 100000.0
# after move 100000 1030 1030
# j = 15 winner is draw
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 61490.0 ('s', 11)('h', 14)
# p2 player, money hand: Random Player 38510.0 ('s', 13)('d', 13)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 6 6
# working len
# MC hands:  ('s', 11) ('h', 14)
# 각자 베팅 1180 -1
# reward, done 1 True
# MC Player 잔고: 61690.0, Random Player 잔고: 38310.0 잔고합계 100000.0
# after move 100000.0 1180 -1
# j = 16 winner is p1(MC Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 61690.0 ('h', 6)('s', 6)
# p2 player, money hand: Random Player 38310.0 ('d', 7)('c', 13)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 6 6
# working len
# MC hands:  ('h', 6) ('s', 6)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 6 6
# working len
# MC hands:  ('h', 6) ('s', 6)
# 각자 베팅 880 1410
# reward, done 1 True
# MC Player 잔고: 63300.0, Random Player 잔고: 36700.0 잔고합계 100000.0
# after move 100000.0 880 1410
# j = 17 winner is p1(MC Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 63300.0 ('s', 10)('s', 4)
# p2 player, money hand: Random Player 36700.0 ('d', 11)('d', 9)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 6 6
# working len
# MC hands:  ('s', 9) ('d', 9)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 6 6
# working len
# MC hands:  ('s', 9) ('d', 9)
# 각자 베팅 1000 1220
# reward, done 1 True
# MC Player 잔고: 64720.0, Random Player 잔고: 35280.0 잔고합계 100000.0
# after move 100000.0 1000 1220
# j = 18 winner is p1(MC Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 64720.0 ('c', 4)('h', 11)
# p2 player, money hand: Random Player 35280.0 ('s', 10)('s', 9)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 6 6
# working len
# MC hands:  ('s', 9) ('d', 9)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 6 6
# working len
# MC hands:  ('s', 9) ('d', 9)
# 각자 베팅 2000 2000
# reward, done 1 True
# MC Player 잔고: 66920.0, Random Player 잔고: 33080.0 잔고합계 100000.0
# after move 100000.0 2000 2000
# j = 19 winner is p1(MC Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 66920.0 ('h', 11)('s', 10)
# p2 player, money hand: Random Player 33080.0 ('d', 8)('c', 6)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 6 6
# working len
# MC hands:  ('h', 11) ('s', 10)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 6 6
# working len
# MC hands:  ('h', 11) ('s', 10)
# 각자 베팅 690 1080
# reward, done 1 True
# MC Player 잔고: 68200.0, Random Player 잔고: 31800.0 잔고합계 100000.0
# after move 100000.0 690 1080
# j = 20 winner is p1(MC Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 68200.0 ('s', 8)('c', 8)
# p2 player, money hand: Random Player 31800.0 ('d', 9)('c', 7)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 6 6
# working len
# MC hands:  ('s', 5) ('s', 6)
# 각자 베팅 -1 1900
# reward, done -1 True
# MC Player 잔고: 68000.0, Random Player 잔고: 32000.0 잔고합계 100000.0
# after move 100000.0 -1 1900
# j = 21 winner is p2(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 68000.0 ('d', 8)('d', 9)
# p2 player, money hand: Random Player 32000.0 ('s', 14)('d', 7)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 6 6
# working len
# MC hands:  ('d', 8) ('d', 9)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 6 6
# working len
# MC hands:  ('d', 8) ('d', 9)
# 각자 베팅 890 1480
# reward, done 1 True
# MC Player 잔고: 69680.0, Random Player 잔고: 30320.0 잔고합계 100000.0
# after move 100000.0 890 1480
# j = 22 winner is p1(MC Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 69680.0 ('s', 13)('c', 7)
# p2 player, money hand: Random Player 30320.0 ('s', 4)('c', 6)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 6 6
# working len
# MC hands:  ('s', 9) ('d', 9)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 6 6
# working len
# MC hands:  ('s', 9) ('d', 9)
# 각자 베팅 1100 1800
# reward, done 1 True
# MC Player 잔고: 71680.0, Random Player 잔고: 28320.0 잔고합계 100000.0
# after move 100000.0 1100 1800
# j = 23 winner is p1(MC Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 71680.0 ('d', 3)('c', 3)
# p2 player, money hand: Random Player 28320.0 ('s', 8)('d', 6)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n']
# y_count , bluff.count('y') 7 6
# working y
# ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n']
# MC hands:  ('d', 3) ('c', 3)
# 각자 베팅 1870 1870
# reward, done 1 True
# MC Player 잔고: 73750.0, Random Player 잔고: 26250.0 잔고합계 100000.0
# after move 100000.0 1870 1870
# j = 24 winner is p1(MC Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 73750.0 ('c', 8)('h', 13)
# p2 player, money hand: Random Player 26250.0 ('d', 14)('s', 5)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n']
# y_count , bluff.count('y') 7 7
# working len
# MC hands:  ('c', 8) ('h', 13)
# 각자 베팅 -1 1610
# reward, done -1 True
# MC Player 잔고: 73550.0, Random Player 잔고: 26450.0 잔고합계 100000.0
# after move 100000.0 -1 1610
# j = 25 winner is p2(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 73550.0 ('s', 13)('h', 11)
# p2 player, money hand: Random Player 26450.0 ('s', 14)('c', 4)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n']
# y_count , bluff.count('y') 7 7
# working len
# MC hands:  ('s', 5) ('s', 6)
# 각자 베팅 -1 1900
# reward, done -1 True
# MC Player 잔고: 73350.0, Random Player 잔고: 26650.0 잔고합계 100000.0
# after move 100000.0 -1 1900
# j = 26 winner is p2(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 73350.0 ('s', 5)('s', 4)
# p2 player, money hand: Random Player 26650.0 ('h', 6)('d', 9)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n']
# y_count , bluff.count('y') 7 7
# working len
# MC hands:  ('s', 9) ('d', 9)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n']
# y_count , bluff.count('y') 7 7
# working len
# MC hands:  ('s', 9) ('d', 9)
# 각자 베팅 1080 1330
# reward, done 1 True
# MC Player 잔고: 74880.0, Random Player 잔고: 25120.0 잔고합계 100000.0
# after move 100000.0 1080 1330
# j = 27 winner is p1(MC Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 74880.0 ('s', 5)('s', 4)
# p2 player, money hand: Random Player 25120.0 ('c', 4)('h', 10)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n']
# y_count , bluff.count('y') 7 7
# working len
# MC hands:  ('s', 5) ('s', 4)
# 각자 베팅 -1 670
# reward, done -1 True
# MC Player 잔고: 74680.0, Random Player 잔고: 25320.0 잔고합계 100000.0
# after move 100000.0 -1 670
# j = 28 winner is p2(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 74680.0 ('c', 7)('c', 14)
# p2 player, money hand: Random Player 25320.0 ('d', 5)('s', 9)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n']
# y_count , bluff.count('y') 7 7
# working len
# MC hands:  ('s', 5) ('s', 6)
# 각자 베팅 -1 220
# reward, done -1 True
# MC Player 잔고: 74480.0, Random Player 잔고: 25520.0 잔고합계 100000.0
# after move 100000.0 -1 220
# j = 29 winner is p2(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 74480.0 ('c', 11)('h', 2)
# p2 player, money hand: Random Player 25520.0 ('s', 11)('h', 10)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n']
# y_count , bluff.count('y') 7 7
# working len
# MC hands:  ('s', 9) ('d', 9)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n']
# y_count , bluff.count('y') 7 7
# working len
# MC hands:  ('s', 9) ('d', 9)
# 각자 베팅 1000 2000
# reward, done 1 True
# MC Player 잔고: 76680.0, Random Player 잔고: 23320.0 잔고합계 100000.0
# after move 100000.0 1000 2000
# j = 30 winner is p1(MC Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 76680.0 ('d', 8)('h', 3)
# p2 player, money hand: Random Player 23320.0 ('s', 14)('h', 4)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n']
# y_count , bluff.count('y') 7 7
# working len
# MC hands:  ('d', 8) ('h', 3)
# 각자 베팅 -1 1770
# reward, done -1 True
# MC Player 잔고: 76480.0, Random Player 잔고: 23520.0 잔고합계 100000.0
# after move 100000.0 -1 1770
# j = 31 winner is p2(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 76480.0 ('d', 2)('d', 3)
# p2 player, money hand: Random Player 23520.0 ('s', 13)('d', 14)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n']
# y_count , bluff.count('y') 7 7
# working len
# MC hands:  ('d', 2) ('d', 3)
# 각자 베팅 -1 1360
# reward, done -1 True
# MC Player 잔고: 76280.0, Random Player 잔고: 23720.0 잔고합계 100000.0
# after move 100000.0 -1 1360
# j = 32 winner is p2(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 76280.0 ('c', 10)('s', 8)
# p2 player, money hand: Random Player 23720.0 ('h', 6)('c', 7)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n']
# y_count , bluff.count('y') 7 7
# working len
# MC hands:  ('s', 9) ('d', 9)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n']
# y_count , bluff.count('y') 7 7
# working len
# MC hands:  ('s', 9) ('d', 9)
# 각자 베팅 1120 1620
# reward, done 1 True
# MC Player 잔고: 78100.0, Random Player 잔고: 21900.0 잔고합계 100000.0
# after move 100000.0 1120 1620
# j = 33 winner is p1(MC Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 78100.0 ('c', 10)('h', 2)
# p2 player, money hand: Random Player 21900.0 ('c', 4)('h', 12)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n']
# y_count , bluff.count('y') 7 7
# working len
# MC hands:  ('s', 9) ('d', 9)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n']
# y_count , bluff.count('y') 7 7
# working len
# MC hands:  ('s', 9) ('d', 9)
# 각자 베팅 900 1680
# reward, done 1 True
# MC Player 잔고: 79980.0, Random Player 잔고: 20020.0 잔고합계 100000.0
# after move 100000.0 900 1680
# j = 34 winner is p1(MC Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 79980.0 ('d', 8)('d', 10)
# p2 player, money hand: Random Player 20020.0 ('c', 13)('h', 3)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n']
# y_count , bluff.count('y') 7 7
# working len
# MC hands:  ('d', 8) ('d', 10)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n']
# y_count , bluff.count('y') 7 7
# working len
# MC hands:  ('d', 8) ('d', 10)
# 각자 베팅 2000 2000
# reward, done 1 True
# MC Player 잔고: 82180.0, Random Player 잔고: 17820.0 잔고합계 100000.0
# after move 100000.0 2000 2000
# j = 35 winner is p1(MC Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 82180.0 ('s', 8)('s', 13)
# p2 player, money hand: Random Player 17820.0 ('h', 6)('c', 9)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n']
# y_count , bluff.count('y') 8 7
# working y
# ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n']
# MC hands:  ('s', 8) ('s', 13)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'n', 'n']
# y_count , bluff.count('y') 8 8
# working len
# MC hands:  ('s', 8) ('s', 13)
# 각자 베팅 870 1500
# reward, done 1 True
# MC Player 잔고: 83880.0, Random Player 잔고: 16120.0 잔고합계 100000.0
# after move 100000.0 870 1500
# j = 36 winner is p1(MC Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 83880.0 ('c', 6)('h', 6)
# p2 player, money hand: Random Player 16120.0 ('c', 4)('h', 5)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'n', 'n']
# y_count , bluff.count('y') 8 8
# working len
# MC hands:  ('c', 6) ('h', 6)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'n', 'n']
# y_count , bluff.count('y') 8 8
# working len
# MC hands:  ('c', 6) ('h', 6)
# 각자 베팅 990 1850
# reward, done 1 True
# MC Player 잔고: 85930.0, Random Player 잔고: 14070.0 잔고합계 100000.0
# after move 100000.0 990 1850
# j = 37 winner is p1(MC Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 85930.0 ('c', 7)('c', 3)
# p2 player, money hand: Random Player 14070.0 ('c', 2)('s', 11)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'n', 'n']
# y_count , bluff.count('y') 8 8
# working len
# MC hands:  ('s', 9) ('d', 9)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'n', 'n']
# y_count , bluff.count('y') 8 8
# working len
# MC hands:  ('s', 9) ('d', 9)
# 각자 베팅 690 1350
# reward, done 1 True
# MC Player 잔고: 87480.0, Random Player 잔고: 12520.0 잔고합계 100000.0
# after move 100000.0 690 1350
# j = 38 winner is p1(MC Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 87480.0 ('h', 4)('c', 8)
# p2 player, money hand: Random Player 12520.0 ('s', 5)('d', 12)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'n', 'n']
# y_count , bluff.count('y') 8 8
# working len
# MC hands:  ('s', 9) ('d', 9)
# 각자 베팅 1630 1630
# reward, done 1 True
# MC Player 잔고: 89310.0, Random Player 잔고: 10690.0 잔고합계 100000.0
# after move 100000.0 1630 1630
# j = 39 winner is p1(MC Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 89310.0 ('s', 10)('h', 7)
# p2 player, money hand: Random Player 10690.0 ('h', 12)('h', 5)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'n', 'n']
# y_count , bluff.count('y') 8 8
# working len
# MC hands:  ('s', 10) ('h', 7)
# 각자 베팅 -1 1860
# reward, done -1 True
# MC Player 잔고: 89110.0, Random Player 잔고: 10890.0 잔고합계 100000.0
# after move 100000.0 -1 1860
# j = 40 winner is p2(Random Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 89110.0 ('s', 14)('d', 12)
# p2 player, money hand: Random Player 10890.0 ('c', 11)('s', 8)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'n', 'n']
# y_count , bluff.count('y') 8 8
# working len
# MC hands:  ('s', 14) ('d', 12)
# 각자 베팅 1770 1770
# reward, done 1 True
# MC Player 잔고: 91080.0, Random Player 잔고: 8920.0 잔고합계 100000.0
# after move 100000.0 1770 1770
# j = 41 winner is p1(MC Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 91080.0 ('d', 8)('h', 2)
# p2 player, money hand: Random Player 8920.0 ('c', 9)('s', 5)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'n', 'n']
# y_count , bluff.count('y') 9 8
# working y
# ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'n', 'n']
# MC hands:  ('s', 9) ('d', 9)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'n']
# y_count , bluff.count('y') 9 9
# working len
# MC hands:  ('s', 9) ('d', 9)
# 각자 베팅 900 1570
# reward, done 1 True
# MC Player 잔고: 92850.0, Random Player 잔고: 7150.0 잔고합계 100000.0
# after move 100000.0 900 1570
# j = 42 winner is p1(MC Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 92850.0 ('d', 5)('c', 13)
# p2 player, money hand: Random Player 7150.0 ('c', 4)('h', 14)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'n']
# y_count , bluff.count('y') 9 9
# working len
# MC hands:  ('s', 9) ('d', 9)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'n']
# y_count , bluff.count('y') 9 9
# working len
# MC hands:  ('s', 9) ('d', 9)
# 각자 베팅 990 1680
# reward, done 1 True
# MC Player 잔고: 94730.0, Random Player 잔고: 5270.0 잔고합계 100000.0
# after move 100000.0 990 1680
# j = 43 winner is p1(MC Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 94730.0 ('c', 4)('s', 7)
# p2 player, money hand: Random Player 5270.0 ('d', 6)('s', 5)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'n']
# y_count , bluff.count('y') 9 9
# working len
# MC hands:  ('s', 9) ('d', 9)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'n']
# y_count , bluff.count('y') 9 9
# working len
# MC hands:  ('s', 9) ('d', 9)
# 각자 베팅 560 1010
# reward, done 1 True
# MC Player 잔고: 95940.0, Random Player 잔고: 4060.0 잔고합계 100000.0
# after move 100000.0 560 1010
# j = 44 winner is p1(MC Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 95940.0 ('c', 5)('d', 6)
# p2 player, money hand: Random Player 4060.0 ('h', 14)('c', 10)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'n']
# y_count , bluff.count('y') 9 9
# working len
# MC hands:  ('s', 9) ('d', 9)
# 각자 베팅 1510 -1
# reward, done 1 True
# MC Player 잔고: 96140.0, Random Player 잔고: 3860.0 잔고합계 100000.0
# after move 100000.0 1510 -1
# j = 45 winner is p1(MC Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 96140.0 ('c', 9)('h', 9)
# p2 player, money hand: Random Player 3860.0 ('d', 11)('s', 2)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'n']
# y_count , bluff.count('y') 9 9
# working len
# MC hands:  ('c', 9) ('h', 9)
# 각자 베팅 1490 -1
# reward, done 1 True
# MC Player 잔고: 96340.0, Random Player 잔고: 3660.0 잔고합계 100000.0
# after move 100000.0 1490 -1
# j = 46 winner is p1(MC Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 96340.0 ('s', 3)('d', 4)
# p2 player, money hand: Random Player 3660.0 ('c', 14)('d', 10)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'n']
# y_count , bluff.count('y') 9 9
# working len
# MC hands:  ('s', 9) ('d', 9)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'n']
# y_count , bluff.count('y') 9 9
# working len
# MC hands:  ('s', 9) ('d', 9)
# 각자 베팅 690 900
# reward, done 1 True
# MC Player 잔고: 97440.0, Random Player 잔고: 2560.0 잔고합계 100000.0
# after move 100000.0 690 900
# j = 47 winner is p1(MC Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 97440.0 ('c', 3)('h', 9)
# p2 player, money hand: Random Player 2560.0 ('c', 13)('c', 2)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'n']
# y_count , bluff.count('y') 9 9
# working len
# MC hands:  ('s', 9) ('d', 9)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'n']
# y_count , bluff.count('y') 9 9
# working len
# MC hands:  ('s', 9) ('d', 9)
# 각자 베팅 760 2000
# reward, done 1 True
# MC Player 잔고: 99640.0, Random Player 잔고: 360.0 잔고합계 100000.0
# after move 100000.0 760 2000
# j = 48 winner is p1(MC Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 99640.0 ('d', 10)('c', 9)
# p2 player, money hand: Random Player 360.0 ('d', 9)('s', 3)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'n']
# y_count , bluff.count('y') 9 9
# working len
# MC hands:  ('s', 9) ('d', 9)
# bluff:  ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'n']
# y_count , bluff.count('y') 9 9
# working len
# MC hands:  ('s', 9) ('d', 9)
# 각자 베팅 1500 1880
# reward, done 1 True
# MC Player 잔고: 101720.0, Random Player 잔고: -1720.0 잔고합계 100000.0
# after move 100000.0 1500 1880
# j = 49 winner is p1(MC Player)
#
# ------------------------------------------------------------------------------------------------------------------
# p1 player, money, hand : MC Player 101720.0 ('c', 14)('c', 4)
# p2 player, money hand: Random Player -1720.0 ('s', 5)('c', 8)
# Player Balance Under 0, End this Game.
#
# Good Game!
#
# 현재 라운드: 51
# MC Player 승리 횟수: 34 Random Player 승리 횟수: 15 비긴 횟수: 1
# MC Player 잔고: 101720.0, Random Player 잔고: -1720.0 잔고합계 100000.0
# 수행 시간: 162.54051685333252
